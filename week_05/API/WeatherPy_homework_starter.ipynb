# %% [markdown]
# # Assignment - What's the Weather Like?
#
# ## Background
#
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: _"Duh. It gets hotter..."_
#
# But, if pressed, how would you **provide evidence**?
#
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it's being processed with the city number and city name.
# * OPTIONAL: Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib ,Seaborn or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
#
# ## Hints and Considerations
#
# * The city data is generated based on random coordinates; as such, your outputs will not be an exact match to the provided starter notebook.
#
# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy).
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Don't modify this cell.
# Dependencies and Setup
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Don't modify this cell
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# A lot of starter code has been generated for you. Use the cell below to play with the data to ensure you know what's happening.

# %%
print(cities)
# Out:
# ['aflu', 'hilo', 'prince rupert', 'tiksi', 'belushya guba', 'kaitangata', 'ushuaia', 'hami', 'rikitea', 'castro', 'barentsburg', 'dikson', 'carutapera', 'mujiayingzi', 'ketchikan', 'barrow', 'hokitika', 'ponta do sol', 'bredasdorp', 'tuktoyaktuk', 'mar del plata', 'bethel', 'bluff', 'khonuu', 'grand river south east', 'taybad', 'albany', 'ahipara', 'mys shmidta', 'hithadhoo', 'vaini', 'lalmohan', 'tiarei', 'lebu', 'new norfolk', 'tasiilaq', 'williams lake', 'port hedland', 'palafrugell', 'kemijarvi', 'bengkulu', 'pelym', 'atuona', 'abnub', 'illoqqortoormiut', 'itarema', 'east london', 'nanzhou', 'axim', 'mataura', 'kudahuvadhoo', 'darhan', 'airai', 'mehamn', 'jamestown', 'kaohsiung', 'qaanaaq', 'lake city', 'codrington', 'isangel', 'gorontalo', 'mount gambier', 'victoria', 'busselton', 'longyan', 'paamiut', 'hermanus', 'khatanga', 'manicore', 'ribeira grande', 'taolanaro', 'kochevo', 'tsihombe', 'yeppoon', 'haimen', 'thai binh', 'clermont', 'santiago del estero', 'mrirt', 'kalabo', 'kapaa', 'cabo san lucas', 'yellowknife', 'pocone', 'moose factory', 'vila velha', 'pevek', 'saskylakh', 'punta arenas', 'palmer', 'camacha', 'port elizabeth', 'pathein', 'tromso', 'nizhneyansk', 'georgetown', 'sao joao da barra', 'port alfred', 'taoudenni', 'basco', 'hamilton', 'ostrovnoy', 'puerto del rosario', 'upernavik', 'tongchuan', 'hobart', 'beyneu', 'attawapiskat', 'cape town', 'eforie', 'darapidap', 'la ronge', 'bababe', 'nikolskoye', 'lavrentiya', 'fukue', 'montenegro', 'brodokalmak', 'athens', 'choszczno', 'cherskiy', 'severo-kurilsk', 'mizan teferi', 'faanui', 'uusikaupunki', 'kaeo', 'muisne', 'liepaja', 'thompson', 'geraldton', 'ushtobe', 'chivay', 'mayo', 'tucupita', 'saint george', 'cidreira', 'bowen', 'sakaiminato', 'oneonta', 'avarua', 'katsuura', 'luderitz', 'paranaiba', 'yumen', 'khao wong', 'bardsir', 'porto novo', 'jaguey grande', 'butaritari', 'tabou', 'saint-francois', 'kodiak', 'erenhot', 'broken hill', 'ziniare', 'carnarvon', 'mayskiy', 'reoti', 'ust-ishim', 'nanortalik', 'ancud', 'jackson', 'chuy', 'hit', 'tual', 'melong', 'provideniya', 'magadan', 'berlevag', 'haibowan', 'solovetskiy', 'lamu', 'manta', 'korla', 'namatanai', 'asau', 'college', 'zemio', 'beringovskiy', 'vestmannaeyjar', 'acari', 'rocha', 'puerto ayora', 'halalo', 'sentyabrskiy', 'warqla', 'laguna', 'lata', 'belmonte', 'wilmington island', 'san patricio', 'yanam', 'morgan city', 'caravelas', 'vaitupu', 'cedar city', 'severo-yeniseyskiy', 'ustyuzhna', 'raudeberg', 'kautokeino', 'talnakh', 'skovorodino', 'port macquarie', 'sao paulo de olivenca', 'houma', 'honningsvag', 'hamina', 'plettenberg bay', 'petropavlovsk-kamchatskiy', 'along', 'lompoc', 'castlegar', 'severodvinsk', 'chokurdakh', 'touros', 'grants', 'amga', 'flers', 'singkang', 'takoradi', 'saint-philippe', 'sobolevo', 'harper', 'waingapu', 'necochea', 'luena', 'maldonado', 'debica', 'sao filipe', 'haltern', 'amderma', 'kalmunai', 'vredendal', 'vao', 'ngunguru', 'khandwa', 'utiroa', 'yinchuan', 'viedma', 'rastolita', 'kamaishi', 'komsomolskiy', 'westport', 'bilibino', 'ngukurr', 'lorengau', 'louisbourg', 'kavieng', 'oistins', 'fort nelson', 'marovoay', 'marienburg', 'fairbanks', 'sao felix do xingu', 'inongo', 'urubicha', 'sitka', 'srednekolymsk', 'khandyga', 'safaga', 'camopi', 'tsienyane', 'fortuna', 'gamba', 'saleaula', 'formosa do rio preto', 'urdzhar', 'terney', 'gurskoye', 'constitucion', 'mazara del vallo', 'tessalit', 'norman wells', 'arraial do cabo', 'hun', 'quatre cocos', 'cracow', 'verkhnevilyuysk', 'seshcha', 'tawkar', 'mata', 'klaksvik', 'kamina', 'guanica', 'margate', 'alofi', 'aykhal', 'opotiki', 'inirida', 'kloulklubed', 'gazojak', 'sakyla', 'salima', 'champerico', 'sorvag', 'lastoursville', 'cayenne', 'beloha', 'marsh harbour', 'barillas', 'krizevci', 'kahului', 'odda', 'dhidhdhoo', 'torbat-e jam', 'newala', 'snyder', 'balikpapan', 'evensk', 'lakes entrance', 'pipar', 'kuantan', 'henties bay', 'dogondoutchi', 'wadi maliz', 'kruisfontein', 'opuwo', 'pokosnoye', 'puerto leguizamo', 'moo ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city in `cities` using a series of successive API calls. Think: how do you do anything successively?
# * Make sure each city in your dataset includes coordinates, country, max temperature, pressure, humidity and wind speed
# * Use a try-except to handle errors (they will occur)
# * Include a print log of each city as it'sbeing processed (with the city number and city name). City number is just going to count which city is being processed

# %%
city_weather = {'City':[],
                'Cloudiness':[],
                'Country':[],
                'Date':[],
               'Humidity':[],
                'Lat':[],
                'Lng':[],
                'Max Temp':[],
                "Wind Speed":[]
               }

#loop over cities and add data to dictionary
for number,city in enumerate(cities):
    base_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + api_key

    try:
        #q represents the city
        req = requests.get(base_url + f'&q={city}')
        
        data = req.json()
        
        #add values to our city_weather dictionary
        city_weather['City'].append(data['name'])
        city_weather['Cloudiness'].append(data['clouds']['all'])
        city_weather['Country'].append(data['sys']['country'])
        city_weather['Date'].append(data['sys']['sunrise'])
        city_weather['Humidity'].append(data['main']['humidity'])
        city_weather['Lat'].append(data['coord']['lat'])
        city_weather['Lng'].append(data['coord']['lon'])
        city_weather['Max Temp'].append(data['main']['temp_max'])
        city_weather['Wind Speed'].append(data['wind']['speed'])
        print(str(number+1)+" processing " + city)
        #note: data['id'] --> api stops working
    except:
        print(city+ " not found")
        pass
# Out:
# aflu not found
# 2 processing hilo
# 3 processing prince rupert
# 4 processing tiksi
# belushya guba not found
# 6 processing kaitangata
# 7 processing ushuaia
# 8 processing hami
# 9 processing rikitea
# 10 processing castro
# barentsburg not found
# 12 processing dikson
# 13 processing carutapera
# 14 processing mujiayingzi
# 15 processing ketchikan
# 16 processing barrow
# 17 processing hokitika
# 18 processing ponta do sol
# 19 processing bredasdorp
# 20 processing tuktoyaktuk
# 21 processing mar del plata
# 22 processing bethel
# 23 processing bluff
# khonuu not found
# grand river south east not found
# 26 processing taybad
# 27 processing albany
# 28 processing ahipara
# mys shmidta not found
# 30 processing hithadhoo
# 31 processing vaini
# 32 processing lalmohan
# 33 processing tiarei
# 34 processing lebu
# 35 processing new norfolk
# 36 processing tasiilaq
# 37 processing williams lake
# 38 processing port hedland
# 39 processing palafrugell
# 40 processing kemijarvi
# 41 processing bengkulu
# 42 processing pelym
# 43 processing atuona
# 44 processing abnub
# illoqqortoormiut not found
# 46 processing itarema
# 47 processing east london
# 48 processing nanzhou
# 49 processing axim
# 50 processing mataura
# 51 processing kudahuvadhoo
# 52 processing darhan
# 53 processing airai
# 54 processing mehamn
# 55 processing jamestown
# 56 processing kaohsiung
# 57 processing qaanaaq
# 58 processing lake city
# 59 processing codrington
# 60 processing isangel
# 61 processing gorontalo
# 62 processing mount gambier
# 63 processing victoria
# 64 processing busselton
# 65 processing longyan
# 66 processing paamiut
# 67 processing hermanus
# 68 processing khatanga
# 69 processing manicore
# 70 processing ribeira grande
# taolanaro not found
# 72 processing kochevo
# tsihombe not found
# 74 processing yeppoon
# 75 processing haimen
# 76 processing thai binh
# 77 processing clermont
# 78 processing santiago del estero
# mrirt not found
# 80 processing kalabo
# 81 processing kapaa
# 82 processing cabo san lucas
# 83 processing yellowknife
# 84 processing pocone
# 85 processing moose factory
# 86 processing vila velha
# 87 processing pevek
# 88 processing saskylakh
# 89 processing punta arenas
# 90 processing palmer
# 91 processing camacha
# 92 processing port elizabeth
# 93 processing pathein
# 94 processing tromso
# nizhneyansk not found
# 96 processing georgetown
# 97 processing sao joao da barra
# 98 processing port alfred
# 99 processing taoudenni
# 100 processing basco
# 101 processing hamilton
# 102 processing ostrovnoy
# 103 processing puerto del rosario
# 104 processing upernavik
# 105 processing tongchuan
# 106 processing hobart
# 107 processing beyneu
# attawapiskat not found
# 109 processing cape town
# eforie not found
# 111 processing darapidap
# 112 processing la ronge
# bababe not found
# 114 processing nikolskoye
# 115 processing lavrentiya
# 116 processing fukue
# 117 processing montenegro
# 118 processing brodokalmak
# 119 processing athens
# 120 processing choszczno
# 121 processing cherskiy
# 122 processing severo-kurilsk
# 123 processing mizan teferi
# 124 processing faanui
# 125 processing uusikaupunki
# 126 processing kaeo
# 127 processing muisne
# 128 processing liepaja
# 129 processing thompson
# 130 processing geraldton
# 131 processing ushtobe
# 132 processing chivay
# 133 processing mayo
# 134 processing tucupita
# 135 processing saint george
# 136 processing cidreira
# 137 processing bowen
# 138 processing sakaiminato
# 139 processing oneonta
# 140 processing avarua
# 141 processing katsuura
# 142 processing luderitz
# 143 processing paranaiba
# 144 processing yumen
# 145 processing khao wong
# 146 processing bardsir
# 147 processing porto novo
# 148 processing jaguey grande
# 149 processing butaritari
# 150 processing tabou
# 151 processing saint-francois
# 152 processing kodiak
# 153 processing erenhot
# 154 processing broken hill
# 155 processing ziniare
# 156 processing carnarvon
# 157 processing mayskiy
# 158 processing reoti
# 159 processing ust-ishim
# 160 processing nanortalik
# 161 processing ancud
# 162 processing jackson
# 163 processing chuy
# 164 processing hit
# 165 processing tual
# 166 processing melong
# 167 processing provideniya
# 168 processing magadan
# 169 processing berlevag
# haibowan not found
# solovetskiy not found
# 172 processing lamu
# 173 processing manta
# 174 processing korla
# 175 processing namatanai
# 176 processing asau
# 177 processing college
# 178 processing zemio
# 179 processing beringovskiy
# 180 processing vestmannaeyjar
# 181 processing acari
# 182 processing rocha
# 183 processing puerto ayora
# halalo not found
# sentyabrskiy not found
# warqla not found
# 187 processing laguna
# 188 processing lata
# 189 processing belmonte
# 190 processing wilmington island
# 191 processing san patricio
# 192 processing yanam
# 193 processing morgan city
# 194 processing caravelas
# vaitupu not found
# 196 processing cedar city
# 197 processing severo-yeniseyskiy
# 198 processing ustyuzhna
# 199 processing raudeberg
# 200 processing kautokeino
# 201 processing talnakh
# 202 processing skovorodino
# 203 processing port macquarie
# 204 processing sao paulo de olivenca
# 205 processing houma
# 206 processing honningsvag
# 207 processing hamina
# 208 processing plettenberg bay
# 209 processing petropavlovsk-kamchatskiy
# 210 processing along
# 211 processing lompoc
# 212 processing castlegar
# 213 processing severodvinsk
# 214 processing chokurdakh
# 215 processing touros
# 216 processing grants
# 217 processing amga
# 218 processing flers
# 219 processing singkang
# 220 processing takoradi
# 221 processing saint-philippe
# 222 processing sobolevo
# 223 processing harper
# 224 processing waingapu
# 225 processing necochea
# 226 processing luena
# 227 processing maldonado
# 228 processing debica
# 229 processing sao filipe
# 230 processing haltern
# amderma not found
# 232 processing kalmunai
# 233 processing vredendal
# 234 processing vao
# 235 processing ngunguru
# 236 processing khandwa
# utiroa not found
# 238 processing yinchuan
# 239 processing viedma
# 240 processing rastolita
# 241 processing kamaishi
# 242 processing komsomolskiy
# 243 processing westport
# 244 processing bilibino
# ngukurr not found
# 246 processing lorengau
# louisbourg not found
# 248 processing kavieng
# 249 processing oistins
# 250 processing fort nelson
# 251 processing marovoay
# 252 processing marienburg
# 253 processing fairbanks
# 254 processing sao felix do xingu
# 255 processing inongo
# 256 processing urubicha
# 257 processing sitka
# 258 processing srednekolymsk
# 259 processing khandyga
# 260 processing safaga
# 261 processing camopi
# tsienyane not found
# 263 processing fortuna
# 264 processing gamba
# saleaula not found
# 266 processing formosa do rio preto
# urdzhar not found
# 268 processing terney
# gurskoye not found
# 270 processing constitucion
# 271 processing mazara del vallo
# 272 processing tessalit
# 273 processing norman wells
# 274 processing arraial do cabo
# 275 processing hun
# 276 processing quatre cocos
# 277 processing cracow
# 278 processing verkhnevilyuysk
# 279 processing seshcha
# tawkar not found
# 281 processing mata
# 282 processing klaksvik
# 283 processing kamina
# 284 processing guanica
# 285 processing margate
# 286 processing alofi
# 287 processing aykhal
# 288 processing opotiki
# 289 processing inirida
# 290 processing kloulklubed
# 291 processing gazojak
# 292 processing sakyla
# 293 processing salima
# 294 processing champerico
# sorvag not found
# 296 processing lastoursville
# 297 processing cayenne
# 298 processing beloha
# 299 processing marsh harbour
# 300 processing barillas
# 301 processing krizevci
# 302 processing kahului
# 303 processing odda
# 304 processing dhidhdhoo
# 305 processing torbat-e jam
# 306 processing newala
# 307 processing snyder
# 308 processing balikpapan
# 309 processing evensk
# 310 processing lakes entrance
# 311 processing pipar
# 312 processing kuantan
# 313 processing henties bay
# 314 processing dogondoutchi
# 315 processing wadi maliz
# 316 processing kruisfontein
# 317 processing opuwo
# 318 processing pokosnoye
# 319 processing puerto leguizamo
# 320 processing moorhead
# 321 processing kandrian
# 322 processing seoul
# 323 processing aiken
# 324 processing kirakira
# 325 processing souillac
# 326 processing tuatapere
# 327 processing portland
# umm durman not found
# 329 processing karasburg
# 330 processing pingliang
# samusu not found
# 332 processing longyearbyen
# 333 processing granby
# 334 processing kiruna
# 335 processing edea
# 336 processing chupa
# 337 processing matara
# 338 processing tombouctou
# 339 processing sobradinho
# 340 processing malindi
# 341 processing trincomalee
# 342 processing putina
# 343 processing canberra
# 344 processing vanino
# 345 processing ayagoz
# tumannyy not found
# 347 processing namibe
# 348 processing coihaique
# 349 processing ingham
# 350 processing segovia
# 351 processing port blair
# 352 processing valleyview
# 353 processing falmouth
# 354 processing mazagao
# 355 processing clyde river
# 356 processing coquimbo
# 357 processing alice springs
# 358 processing ussuriysk
# 359 processing sorland
# 360 processing arnprior
# 361 processing sechura
# 362 processing ailigandi
# 363 processing bambous virieux
# lolua not found
# 365 processing mount isa
# 366 processing kato mazarakion
# 367 processing dombarovskiy
# 368 processing berdigestyakh
# 369 processing petropavl
# 370 processing amalapuram
# 371 processing pitimbu
# 372 processing gigmoto
# kamenskoye not found
# 374 processing turkmenabat
# 375 processing bozoum
# 376 processing svetlogorsk
# 377 processing verkhoyansk
# 378 processing aklavik
# 379 processing narsaq
# 380 processing phuket
# 381 processing port lincoln
# 382 processing svay rieng
# 383 processing vostok
# 384 processing puli
# 385 processing damghan
# 386 processing cabedelo
# 387 processing san cristobal
# 388 processing petropavlovka
# felidhoo not found
# 390 processing juan lacaze
# 391 processing vila franca do campo
# 392 processing torbay
# 393 processing baoding
# 394 processing sarangani
# 395 processing loandjili
# 396 processing manggar
# 397 processing tiznit
# 398 processing santa cruz de la palma
# 399 processing shitanjing
# 400 processing rosetown
# 401 processing hammerfest
# 402 processing marystown
# 403 processing qasigiannguit
# 404 processing ugoofaaru
# 405 processing andra
# 406 processing tucuman
# 407 processing columbus
# 408 processing nouadhibou
# 409 processing conde
# 410 processing mahibadhoo
# 411 processing monrovia
# 412 processing saldanha
# 413 processing kholodnyy
# 414 processing katangli
# 415 processing cochabamba
# 416 processing timra
# 417 processing chapais
# 418 processing caiaponia
# 419 processing karwar
# 420 processing tommot
# 421 processing bandarbeyla
# 422 processing puri
# 423 processing mahebourg
# 424 processing batemans bay
# 425 processing mersing
# 426 processing roma
# 427 processing mangrol
# 428 processing hualmay
# 429 processing coahuayana
# 430 processing povazska bystrica
# 431 processing san quintin
# 432 processing puerto escondido
# 433 processing iralaya
# 434 processing liverpool
# 435 processing itoman
# 436 processing canchungo
# 437 processing tateyama
# 438 processing novyy urgal
# 439 processing bubaque
# 440 processing port augusta
# 441 processing anshun
# 442 processing tsnori
# 443 processing montauban
# 444 processing los llanos de aridane
# 445 processing faya
# 446 processing khryashchevka
# 447 processing marawi
# 448 processing nantucket
# 449 processing kailua
# 450 processing blythe
# 451 processing urmary
# 452 processing pinawa
# 453 processing zabaykalsk
# 454 processing lanaken
# 455 processing amapa
# 456 processing ossora
# bolungarvik not found
# 458 processing kharp
# 459 processing anadyr
# 460 processing balotra
# 461 processing ryazan
# 462 processing huaibei
# 463 processing havelock
# 464 processing yar-sale
# 465 processing guerrero negro
# 466 processing cavalcante
# 467 processing hansot
# zhanatas not found
# 469 processing sinop
# 470 processing palpa
# 471 processing turan
# 472 processing iqaluit
# 473 processing nha trang
# 474 processing te anau
# 475 processing malatya
# 476 processing menomonie
# 477 processing guiuan
# 478 processing kargopol
# 479 processing niteroi
# 480 processing the pas
# 481 processing esperance
# 482 processing montepuez
# 483 processing nyurba
# 484 processing conceicao do araguaia
# 485 processing semenyih
# 486 processing mitchell
# 487 processing aventura
# 488 processing asaba
# 489 processing pangody
# 490 processing talant
# sinjah not found
# 492 processing abha
# 493 processing urumqi
# 494 processing tocopilla
# 495 processing voh
# 496 processing murgab
# 497 processing leshukonskoye
# 498 processing gidam
# 499 processing sangmelima
# 500 processing alihe
# 501 processing lovington
# 502 processing virginia
# 503 processing fare
# 504 processing kaduqli
# 505 processing cam ranh
# 506 processing alexandria
# 507 processing salalah
# 508 processing port hardy
# 509 processing kaihua
# 510 processing macon
# 511 processing morros
# 512 processing atherton
# 513 processing padang
# 514 processing itapeva
# 515 processing tecoanapa
# 516 processing san carlos
# 517 processing derzhavinsk
# 518 processing portree
# 519 processing changli
# 520 processing trairi
# 521 processing rio gallegos
# 522 processing husavik
# 523 processing abapo
# 524 processing jalu
# 525 processing kibala
# bargal not found
# 527 processing fuzhou
# 528 processing tsaratanana
# 529 processing urambo
# 530 processing pangoa
# 531 processing pisco
# 532 processing puerto madero
# 533 processing mairipora
# 534 processing vardo
# 535 processing biltine
# 536 processing yulara
# 537 processing calabozo
# 538 processing nicosia
# satitoa not found
# toliary not found
# 541 processing bontang
# 542 processing ziro
# 543 processing santa rosa
# 544 processing perth
# 545 processing pangnirtung
# 546 processing poum
# 547 processing half moon bay
# 548 processing chumphon
# 549 processing merritt
# 550 processing akyab
# 551 processing hasaki
# 552 processing ust-ilimsk
# 553 processing avigliano
# 554 processing muros
# 555 processing pochutla
# 556 processing waddan
# 557 processing goderich
# 558 processing nanakuli
# 559 processing mandera
# 560 processing sola
# 561 processing suratgarh
# 562 processing vuktyl
# 563 processing tres arroyos
# 564 processing jardim
# 565 processing kulhudhuffushi
# 566 processing meulaboh
# 567 processing ornskoldsvik
# 568 processing phalaborwa
# 569 processing tura
# 570 processing presidencia roque saenz pena
# 571 processing manokwari
# 572 processing whitehorse
# 573 processing brae
# 574 processing ballina
# 575 processing shellbrook
# 576 processing odenthal
# 577 processing brewster
# 578 processing ust-kan
# 579 processing havre-saint-pierre
# 580 processing sao jose da coroa grande
# 581 processing marrakesh
# 582 processing arona
# 583 processing port-gentil
# 584 processing bereda
# 585 processing nisia floresta
# 586 processing villarrica
# 587 processing san jose
# 588 processing nenjiang
# 589 processing erdenet
# 590 processing grand gaube
# 591 processing avera
# 592 processing apastepeque
# 593 processing challans
# 594 processing amparafaravola
# 595 processing algiers
# 596 processing dwarka
# 597 processing merauke
# 598 processing chumikan
# 599 processing suhbaatar
# 600 processing nizwa
# 601 processing brighton
# 602 processing saryozek
# 603 processing xining

# %%
print(city_weather)
# Out:
# {'City': ['Ambilobe', 'Thompson', 'Busselton', 'Souillac', 'Hualmay', 'Kruisfontein', 'Hithadhoo', 'Hay River', 'Ushuaia', 'Tolbazy', 'Mataura', 'Port Hardy', 'Punta Arenas', 'Bluff', 'Berezovyy', 'Villa Carlos Paz', 'Te Anau', 'Castro', 'Port Alfred', 'Longyearbyen', 'Kaitangata', 'Ribeira Grande', 'Bongandanga', 'Hong Kong', 'Pevek', 'Havøysund', 'Forsytheganj', 'North Platte', 'Hofn', 'Rikitea', 'Isangel', 'Saint-Philippe', 'Puerto Ayora', 'Sørland', 'San Cristobal', 'Nikolskoye', 'Atuona', 'Vanavara', 'Saskylakh', 'Lagoa', 'Lander', 'Yulin', 'Ponta do Sol', 'Butaritari', 'Stepnyak', 'São João da Barra', 'Hobart', 'Iqaluit', 'Hermanus', 'Oussouye', 'Qaanaaq', 'Mount Vernon', 'Lebu', 'Provideniya', 'Palmer', 'Hamilton', 'Jiazi', 'Ust-Kuyga', 'Thurles', 'Yumen', 'Hiroshima', 'Pisco', 'Mtwara', 'Chapais', 'New Norfolk', 'Marabu', 'East London', 'Hilo', 'Avarua', 'Luanda', 'Leh', 'Kapaa', 'Yellowknife', 'Saint-Augustin', 'Kavaratti', 'Santa Isabel Rio Negro', 'Amqui', 'Dingle', 'Port Elizabeth', 'Peniche', 'Ţahţā', 'Hailar', 'Saint George', 'Gondanglegi', 'Meadow Lake', 'Tortoman', 'Samarai', 'Fortuna', 'Sobolevo', 'Albany', 'Ambovombe', 'Amga', 'Avera', 'Cape Town', 'Mahébourg', 'Griffith', 'Morón', 'Safford', 'Vao', 'Jamestown', 'Leningradskiy', 'Arraial do Cabo', 'Tasiilaq', 'Mandapam', 'Barrow', 'Ishigaki', 'Pacific Grove', 'Huejuquilla el Alto', 'Ambanja', 'Khatanga', 'Den Helder', 'George Town', 'Faanui', 'Esperance', 'Aswān', 'Rio Grande', 'Matara', 'Guerrero Negro', 'Buala', 'San Patricio', 'Doaba', 'Bambous Virieux', 'Nome', 'Airai', 'Vardø', 'Cidreira', 'Sinnamary', 'Tiksi', 'Constitución', 'Mar del Plata', 'Tuatapere', 'Padang', 'Safaga', 'Nabire', 'Guangzhou', 'Salalah', 'Codrington', 'Pasni', 'Camaquã', 'Wanning', 'Tura', 'Morristown', 'Vaini', 'Chokurdakh', 'Cairns', 'Bethel', 'Bitkine', 'Sawākin', 'Yenagoa', 'Siderno', 'Dikson', 'Marsá Maţrūḩ', 'Oga', 'Lanzhou', 'Cabo San Lucas', 'Lüderitz', 'Tuktoyaktuk', 'Arcata', 'Mchinji', 'São Filipe', 'Burnie', 'Mount Gambier', 'Ponta Delgada', 'Gräfenhainichen', 'Klaksvík', 'Esim', 'Sitka', 'Fuxin', 'Lompoc', 'Port Lincoln', 'Zyryanka', 'Puerto Maldonado', 'Olafsvik', 'Norman Wells', 'Emba', 'Abu Samrah', 'Othaya', 'Sagamu', 'College', 'Chany', 'Benguela', 'Sangar', 'Iberia', 'Kumul', 'Bengkulu', 'Mehamn', 'Karpathos', 'Carnarvon', 'Matale', 'Altay', 'Ilulissat', 'Huánuco', 'Nador', 'Brae', 'Ngunguru', 'Brigantine', 'Korla', 'Carballo', 'Oodweyne', 'San Ignacio', 'Zhigansk', 'Khor', 'Kars', 'Laas', 'Xining', 'Tara', 'Mitú', 'Manono', 'Joinville', 'Ussel', 'Acapulco de Juárez', 'Huarmey', 'Chui', 'Luena', 'Takoradze', 'Saint Paul Harbor', 'Alexandria', 'Gizo Government Station', 'Sola', 'Omboué', 'Sulangan', 'Bredasdorp', 'Zhangye', 'San Lorenzo', 'Pangnirtung', 'Saint-Joseph', 'Puerto Escondido', 'Opuwo', 'Lavrentiya', 'Port Augusta', 'Liverpool', 'Upernavik', 'Sanguéya', 'Yanam', 'Victor Harbor', 'Balkanabat', 'Alice Springs', 'Mackay', 'Moba', 'Mahon', 'Gwanda', 'Gravdal', 'Broome', 'Anadyr', 'Bilma', 'Ostrovnoy', 'Adamovka', 'Chu', 'La Ronge', 'Katsuura', 'Tūkrah', 'Alenquer', 'Nsanje', 'Cherskiy', 'Hlotse', 'Constantine', 'Ardmore', 'Jacksonville', 'Teya', 'Ponta Porã', 'Obo', 'Tacna', 'Nantucket', 'Mahon', 'Siyabuswa', 'Kuching', "Ust'-Ishim", 'Diamantino', 'Butterworth', 'Cururupu', 'Kavieng', 'Mandera', 'Flinders', 'Gaffney', 'Clyde River', 'Spornoye', 'Nemuro', 'Jodiya', 'Torbay', 'Ranao', 'Senanga', 'Akdepe', 'Pochutla', 'Tarata', 'Harper', 'Batagay', 'Salinópolis', 'Touros', 'Tomatlán', 'Saldanha', 'Coyhaique', 'Karratha', 'Manokwari', 'Paamiut', 'Cabañas', 'Saint Andrews', 'Porto Torres', 'Sorong', 'Beringovskiy', 'Grootfontein', 'Hasaki', 'Shelburne', 'Yambio', 'Jerome', 'Narsaq', 'Devils Lake', 'Trivandrum', 'Novobirilyussy', 'Loksa', 'Olinda', 'Valparaíso', 'Novoagansk', 'Ciudad Bolivar', 'Mount Isa', 'Pitimbu', 'Kysyl-Syr', 'Tonj', 'Murgab', 'Dalvik', 'Berlevåg', 'Bafoulabé', 'Macapá', 'Comodoro Rivadavia', 'Kasongo-Lunda', 'Aklavik', 'Verkhnetulomskiy', 'Up ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Display the DataFrame
# * Export the city data into a .csv. Open it up in excel or another program to make sure it looks as expected

# %%
weather_df = pd.DataFrame.from_dict(city_weather)
weather_df
# Out:
#               City  Cloudiness Country        Date  Humidity      Lat  \
# 0             Hilo          40      US  1634746598        76  19.7297
# 1    Prince Rupert          40      CA  1634743194        87  54.3161
# 2            Tiksi         100      RU  1634771671        93  71.6872
# 3       Kaitangata          31      NZ  1634751301        63 -46.2817
# 4          Ushuaia          40      AR  1634807313        46 -54.8000
# ..             ...         ...     ...         ...       ...      ...
# 556      Sühbaatar           0      MN  1634772393        42  50.2314
# 557          Nizwá          63      OM  1634782141        52  22.9333
# 558       Brighton         100      GB  1634798010        90  50.8284
# 559       Saryozek         100      KZ  1634778619        25  44.3583
# 560         Xining          99      CN  1634772321        76  36.6167
#
#           Lng  Max Temp  Wind Speed
# 0   -155.0900     74.93        5.75
# 1   -130.3201     48.29       11.50
# 2    128.8694     13.89        6.20
# 3    169.8464     49.66        8.08
# 4    -68.3000     46.06       10.36
# ..        ...       ...         ...
# 556  106.2078     45.09        7.25
# 557   57.5333     77.95        1.61
# 558   -0.1395     50.56       14.00
# 559   77.9753     58.12        0.94
# 560  101.7667     42.10        1.32
#
# [561 rows x 9 columns]

# %%
weather_df.count()
# Out:
# City          561
# Cloudiness    561
# Country       561
# Date          561
# Humidity      561
# Lat           561
# Lng           561
# Max Temp      561
# Wind Speed    561
# dtype: int64

# %%
weather_df.to_csv('weather.csv',index=False)

# %%
check_df= pd.read_csv('weather.csv')
check_df
# Out:
#               City  Cloudiness Country        Date  Humidity      Lat  \
# 0             Hilo          40      US  1634746598        76  19.7297
# 1    Prince Rupert          40      CA  1634743194        87  54.3161
# 2            Tiksi         100      RU  1634771671        93  71.6872
# 3       Kaitangata          31      NZ  1634751301        63 -46.2817
# 4          Ushuaia          40      AR  1634807313        46 -54.8000
# ..             ...         ...     ...         ...       ...      ...
# 556      Sühbaatar           0      MN  1634772393        42  50.2314
# 557          Nizwá          63      OM  1634782141        52  22.9333
# 558       Brighton         100      GB  1634798010        90  50.8284
# 559       Saryozek         100      KZ  1634778619        25  44.3583
# 560         Xining          99      CN  1634772321        76  36.6167
#
#           Lng  Max Temp  Wind Speed
# 0   -155.0900     74.93        5.75
# 1   -130.3201     48.29       11.50
# 2    128.8694     13.89        6.20
# 3    169.8464     49.66        8.08
# 4    -68.3000     46.06       10.36
# ..        ...       ...         ...
# 556  106.2078     45.09        7.25
# 557   57.5333     77.95        1.61
# 558   -0.1395     50.56       14.00
# 559   77.9753     58.12        0.94
# 560  101.7667     42.10        1.32
#
# [561 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Use matplotlib
# * Save the plotted figures as .pngs and embed those pngs in your readme file.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig,ax = plt.subplots()
ax.scatter(weather_df["Lat"], weather_df["Max Temp"],color = "steelblue", edgecolor = "black")
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")
ax.set_title("City Latitude vs. Max Temperature (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()
fig.savefig('Lat_Temp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig,ax = plt.subplots()
ax.scatter(weather_df["Lat"], weather_df["Humidity"],color = "steelblue", edgecolor = "black")
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity(%)")
ax.set_title("City Latitude vs. Humidity (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()
fig.savefig('Lat_Humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig,ax = plt.subplots()
ax.scatter(weather_df["Lat"], weather_df["Cloudiness"],color = "steelblue", edgecolor = "black")
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness (%)")
ax.set_title("City Latitude vs. Cloudiness (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()
fig.savefig('Lat_Cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig,ax = plt.subplots()
ax.scatter(weather_df["Lat"], weather_df["Wind Speed"],color = "steelblue", edgecolor = "black")
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (mph)")
ax.set_title("City Latitude vs. Wind Speed (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()
fig.savefig('Lat_Wind Speed.png')

# %% [markdown]
# ### Use the Seaborn library to re-create 2-4 of the above plots.
# * Use the same data just make a different plot.
# * Note the differences in amount of code required to generate a similar plot.

# %%
sns.scatterplot(x=weather_df["Lat"], y=weather_df["Max Temp"],color = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Max Temperature (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %%
sns.scatterplot(x=weather_df["Lat"], y=weather_df["Humidity"],color = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Humidity (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %%
sns.scatterplot(x=weather_df["Lat"], y=weather_df["Cloudiness"],color = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %%
sns.scatterplot(x=weather_df["Lat"], y=weather_df["Wind Speed"],color = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %% [markdown]
# ### As a Data-Scientist:
# In addition to generating data, munging data and plotting data you will also be responsible for *interpreting* data.
# * Provide a written description of three observable trends based on the data.

# %% [markdown]
# - The cities near the equator have the highest temperture while cities farthest from the equator have the lowest temperature. The temperature decreases depending on how much farther the cities are from the equator.
# - Most of cities' wind speed are in the lower range such as 0-10 mph. Some of the cities as it gets closer to the north pole, the wind speed increases as well
# - Most of cities have high humidity level of 80 to 100%

# %% [markdown]
# ### OPTIONAL Homework Problem:
# * Use a **different** api endpoint such as `Hourly Forecast 4 days` to get data.
# * Other weather api endpoints are documented [here](https://openweathermap.org/api).
# * You will have to change the URL parameters to get the data you want.
# * Get the data into a data structure of your choice. (Pandas, dicts, lists etc...)
# * Use the plotting library of your choice to make 1-4 plots of your choice.

# %% [markdown]
# ![Screen%20Shot%202021-10-21%20at%2012.03.18%20AM.png](attachment:Screen%20Shot%202021-10-21%20at%2012.03.18%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202021-10-21%20at%205.45.26%20PM.png](attachment:Screen%20Shot%202021-10-21%20at%205.45.26%20PM.png)
