# %% [markdown]
# # Assignment - What's the Weather Like?
#
# ## Background
#
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: _"Duh. It gets hotter..."_
#
# But, if pressed, how would you **provide evidence**?
#
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it's being processed with the city number and city name.
# * OPTIONAL: Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib ,Seaborn or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
#
# ## Hints and Considerations
#
# * The city data is generated based on random coordinates; as such, your outputs will not be an exact match to the provided starter notebook.
#
# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy).
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Don't modify this cell.
# Dependencies and Setup
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Don't modify this cell
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# A lot of starter code has been generated for you. Use the cell below to play with the data to ensure you know what's happening.

# %%
print(cities)
# Out:
# ['ambilobe', 'thompson', 'busselton', 'souillac', 'hualmay', 'kruisfontein', 'hithadhoo', 'hay river', 'ushuaia', 'tolbazy', 'deh rawud', 'mataura', 'port hardy', 'punta arenas', 'bluff', 'berezovyy', 'villa carlos paz', 'te anau', 'castro', 'port alfred', 'longyearbyen', 'kaitangata', 'ribeira grande', 'bongandanga', 'victoria', 'pevek', 'havoysund', 'svetlogorsk', 'north platte', 'hofn', 'rikitea', 'isangel', 'saint-philippe', 'puerto ayora', 'sorland', 'taolanaro', 'san cristobal', 'nikolskoye', 'atuona', 'vanavara', 'saleaula', 'saskylakh', 'lagoa', 'lander', 'yulin', 'ponta do sol', 'butaritari', 'stepnyak', 'sao joao da barra', 'hobart', 'iqaluit', 'samusu', 'hermanus', 'oussouye', 'qaanaaq', 'mount vernon', 'lebu', 'lolua', 'bargal', 'provideniya', 'palmer', 'hamilton', 'jiazi', 'ust-kuyga', 'thurles', 'yumen', 'hiroshima', 'pisco', 'mtwara', 'chapais', 'new norfolk', 'miri', 'east london', 'hilo', 'avarua', 'luanda', 'leh', 'kapaa', 'rawannawi', 'yellowknife', 'saint-augustin', 'kavaratti', 'santa isabel do rio negro', 'amqui', 'dingle', 'port elizabeth', 'peniche', 'tahta', 'hailar', 'saint george', 'gondanglegi', 'meadow lake', 'tortoman', 'mys shmidta', 'samarai', 'fortuna', 'sobolevo', 'barentsburg', 'mentok', 'albany', 'ambovombe', 'amga', 'avera', 'cape town', 'mahebourg', 'griffith', 'dolbeau', 'moron', 'safford', 'vao', 'jamestown', 'leningradskiy', 'arraial do cabo', 'tasiilaq', 'amderma', 'mandapam', 'barrow', 'ishigaki', 'pacific grove', 'huejuquilla el alto', 'ambanja', 'khatanga', 'den helder', 'georgetown', 'faanui', 'esperance', 'aswan', 'rio grande', 'matara', 'guerrero negro', 'buala', 'san patricio', 'karkaralinsk', 'doaba', 'bambous virieux', 'nome', 'airai', 'vardo', 'cidreira', 'sinnamary', 'tiksi', 'constitucion', 'mar del plata', 'tuatapere', 'padang', 'safaga', 'nabire', 'guangzhou', 'salalah', 'codrington', 'pasni', 'camaqua', 'wanning', 'tura', 'morristown', 'vaini', 'chokurdakh', 'cairns', 'belushya guba', 'bethel', 'bitkine', 'sawakin', 'yenagoa', 'siderno', 'dikson', 'marsa matruh', 'oga', 'lanzhou', 'cabo san lucas', 'luderitz', 'tuktoyaktuk', 'grand river south east', 'arcata', 'mchinji', 'sao filipe', 'burnie', 'mount gambier', 'ponta delgada', 'grafenhainichen', 'klaksvik', 'axim', 'sitka', 'fuxin', 'lompoc', 'sentyabrskiy', 'bolungarvik', 'port lincoln', 'zyryanka', 'chagda', 'puerto maldonado', 'olafsvik', 'norman wells', 'emba', 'abu samrah', 'othaya', 'shagamu', 'college', 'chany', 'benguela', 'sangar', 'iberia', 'hami', 'bengkulu', 'mehamn', 'haapu', 'karpathos', 'carnarvon', 'matale', 'altay', 'ilulissat', 'huanuco', 'nador', 'nizhneyansk', 'brae', 'ngunguru', 'brigantine', 'korla', 'carballo', 'odweyne', 'san ignacio', 'zhigansk', 'khor', 'kars', 'lasa', 'xining', 'tara', 'ruatoria', 'mitu', 'manono', 'joinville', 'ussel', 'acapulco', 'huarmey', 'chuy', 'luena', 'takoradi', 'kodiak', 'alexandria', 'gizo', 'sola', 'omboue', 'sulangan', 'ngukurr', 'bredasdorp', 'zhangye', 'san lorenzo', 'pangnirtung', 'saint-joseph', 'puerto escondido', 'opuwo', 'lavrentiya', 'port augusta', 'liverpool', 'upernavik', 'sangueya', 'palabuhanratu', 'yanam', 'victor harbor', 'balkanabat', 'alice springs', 'mackay', 'moba', 'mahon', 'gwanda', 'gravdal', 'broome', 'tumannyy', 'anadyr', 'bilma', 'ostrovnoy', 'adamovka', 'shu', 'la ronge', 'katsuura', 'tukrah', 'alenquer', 'nsanje', 'cherskiy', 'hlotse', 'tabiauea', 'constantine', 'ardmore', 'jacksonville', 'teya', 'ponta pora', 'obo', 'tacna', 'nantucket', 'mao', 'siyabuswa', 'vaitupu', 'kuching', 'ust-ishim', 'diamantino', 'butterworth', 'cururupu', 'kavieng', 'mandera', 'flinders', 'gaffney', 'clyde river', 'spornoye', 'nemuro', 'jodiya', 'torbay', 'ranao', 'senanga', 'akdepe', 'pochutla', 'tarata', 'harper', 'tsihombe', 'burica', 'batagay', 'salinopolis', 'touros', 'tomatlan', 'saldanha', 'coihaique', 'karratha', 'manokwari', 'paamiut', 'cabanas', 'saint andrews', 'porto torres', 'sorong', 'beringovskiy', 'el faiyum', 'grootfontein', 'hasaki', 'shelbur ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city in `cities` using a series of successive API calls. Think: how do you do anything successively?
# * Make sure each city in your dataset includes coordinates, country, max temperature, pressure, humidity and wind speed
# * Use a try-except to handle errors (they will occur)
# * Include a print log of each city as it'sbeing processed (with the city number and city name). City number is just going to count which city is being processed

# %%
city_weather = {'City':[],
                'Cloudiness':[],
                'Country':[],
                'Date':[],
               'Humidity':[],
                'Lat':[],
                'Lng':[],
                'Max Temp':[],
                "Wind Speed":[]
               }

#loop over cities and add data to dictionary
for number,city in enumerate(cities):
    base_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + api_key

    try:
        #q represents the city
        req = requests.get(base_url + f'&q={city}')
        
        data = req.json()
        
        #add values to our city_weather dictionary
        city_weather['City'].append(data['name'])
        city_weather['Cloudiness'].append(data['clouds']['all'])
        city_weather['Country'].append(data['sys']['country'])
        city_weather['Date'].append(data['sys']['sunrise'])
        city_weather['Humidity'].append(data['main']['humidity'])
        city_weather['Lat'].append(data['coord']['lat'])
        city_weather['Lng'].append(data['coord']['lon'])
        city_weather['Max Temp'].append(data['main']['temp_max'])
        city_weather['Wind Speed'].append(data['wind']['speed'])
        print(str(number+1)+" processing " + city)
        #note: data['id'] --> api stops working
    except:
        print(city+ " not found")
        pass
# Out:
# 1 processing ambilobe
# 2 processing thompson
# 3 processing busselton
# 4 processing souillac
# 5 processing hualmay
# 6 processing kruisfontein
# 7 processing hithadhoo
# 8 processing hay river
# 9 processing ushuaia
# 10 processing tolbazy
# deh rawud not found
# 12 processing mataura
# 13 processing port hardy
# 14 processing punta arenas
# 15 processing bluff
# 16 processing berezovyy
# 17 processing villa carlos paz
# 18 processing te anau
# 19 processing castro
# 20 processing port alfred
# 21 processing longyearbyen
# 22 processing kaitangata
# 23 processing ribeira grande
# 24 processing bongandanga
# 25 processing victoria
# 26 processing pevek
# 27 processing havoysund
# 28 processing svetlogorsk
# 29 processing north platte
# 30 processing hofn
# 31 processing rikitea
# 32 processing isangel
# 33 processing saint-philippe
# 34 processing puerto ayora
# 35 processing sorland
# taolanaro not found
# 37 processing san cristobal
# 38 processing nikolskoye
# 39 processing atuona
# 40 processing vanavara
# saleaula not found
# 42 processing saskylakh
# 43 processing lagoa
# 44 processing lander
# 45 processing yulin
# 46 processing ponta do sol
# 47 processing butaritari
# 48 processing stepnyak
# 49 processing sao joao da barra
# 50 processing hobart
# 51 processing iqaluit
# samusu not found
# 53 processing hermanus
# 54 processing oussouye
# 55 processing qaanaaq
# 56 processing mount vernon
# 57 processing lebu
# lolua not found
# bargal not found
# 60 processing provideniya
# 61 processing palmer
# 62 processing hamilton
# 63 processing jiazi
# 64 processing ust-kuyga
# 65 processing thurles
# 66 processing yumen
# 67 processing hiroshima
# 68 processing pisco
# 69 processing mtwara
# 70 processing chapais
# 71 processing new norfolk
# 72 processing miri
# 73 processing east london
# 74 processing hilo
# 75 processing avarua
# 76 processing luanda
# 77 processing leh
# 78 processing kapaa
# rawannawi not found
# 80 processing yellowknife
# 81 processing saint-augustin
# 82 processing kavaratti
# 83 processing santa isabel do rio negro
# 84 processing amqui
# 85 processing dingle
# 86 processing port elizabeth
# 87 processing peniche
# 88 processing tahta
# 89 processing hailar
# 90 processing saint george
# 91 processing gondanglegi
# 92 processing meadow lake
# 93 processing tortoman
# mys shmidta not found
# 95 processing samarai
# 96 processing fortuna
# 97 processing sobolevo
# barentsburg not found
# mentok not found
# 100 processing albany
# 101 processing ambovombe
# 102 processing amga
# 103 processing avera
# 104 processing cape town
# 105 processing mahebourg
# 106 processing griffith
# dolbeau not found
# 108 processing moron
# 109 processing safford
# 110 processing vao
# 111 processing jamestown
# 112 processing leningradskiy
# 113 processing arraial do cabo
# 114 processing tasiilaq
# amderma not found
# 116 processing mandapam
# 117 processing barrow
# 118 processing ishigaki
# 119 processing pacific grove
# 120 processing huejuquilla el alto
# 121 processing ambanja
# 122 processing khatanga
# 123 processing den helder
# 124 processing georgetown
# 125 processing faanui
# 126 processing esperance
# 127 processing aswan
# 128 processing rio grande
# 129 processing matara
# 130 processing guerrero negro
# 131 processing buala
# 132 processing san patricio
# karkaralinsk not found
# 134 processing doaba
# 135 processing bambous virieux
# 136 processing nome
# 137 processing airai
# 138 processing vardo
# 139 processing cidreira
# 140 processing sinnamary
# 141 processing tiksi
# 142 processing constitucion
# 143 processing mar del plata
# 144 processing tuatapere
# 145 processing padang
# 146 processing safaga
# 147 processing nabire
# 148 processing guangzhou
# 149 processing salalah
# 150 processing codrington
# 151 processing pasni
# 152 processing camaqua
# 153 processing wanning
# 154 processing tura
# 155 processing morristown
# 156 processing vaini
# 157 processing chokurdakh
# 158 processing cairns
# belushya guba not found
# 160 processing bethel
# 161 processing bitkine
# 162 processing sawakin
# 163 processing yenagoa
# 164 processing siderno
# 165 processing dikson
# 166 processing marsa matruh
# 167 processing oga
# 168 processing lanzhou
# 169 processing cabo san lucas
# 170 processing luderitz
# 171 processing tuktoyaktuk
# grand river south east not found
# 173 processing arcata
# 174 processing mchinji
# 175 processing sao filipe
# 176 processing burnie
# 177 processing mount gambier
# 178 processing ponta delgada
# 179 processing grafenhainichen
# 180 processing klaksvik
# 181 processing axim
# 182 processing sitka
# 183 processing fuxin
# 184 processing lompoc
# sentyabrskiy not found
# bolungarvik not found
# 187 processing port lincoln
# 188 processing zyryanka
# chagda not found
# 190 processing puerto maldonado
# 191 processing olafsvik
# 192 processing norman wells
# 193 processing emba
# 194 processing abu samrah
# 195 processing othaya
# 196 processing shagamu
# 197 processing college
# 198 processing chany
# 199 processing benguela
# 200 processing sangar
# 201 processing iberia
# 202 processing hami
# 203 processing bengkulu
# 204 processing mehamn
# haapu not found
# 206 processing karpathos
# 207 processing carnarvon
# 208 processing matale
# 209 processing altay
# 210 processing ilulissat
# 211 processing huanuco
# 212 processing nador
# nizhneyansk not found
# 214 processing brae
# 215 processing ngunguru
# 216 processing brigantine
# 217 processing korla
# 218 processing carballo
# 219 processing odweyne
# 220 processing san ignacio
# 221 processing zhigansk
# 222 processing khor
# 223 processing kars
# 224 processing lasa
# 225 processing xining
# 226 processing tara
# ruatoria not found
# 228 processing mitu
# 229 processing manono
# 230 processing joinville
# 231 processing ussel
# 232 processing acapulco
# 233 processing huarmey
# 234 processing chuy
# 235 processing luena
# 236 processing takoradi
# 237 processing kodiak
# 238 processing alexandria
# 239 processing gizo
# 240 processing sola
# 241 processing omboue
# 242 processing sulangan
# ngukurr not found
# 244 processing bredasdorp
# 245 processing zhangye
# 246 processing san lorenzo
# 247 processing pangnirtung
# 248 processing saint-joseph
# 249 processing puerto escondido
# 250 processing opuwo
# 251 processing lavrentiya
# 252 processing port augusta
# 253 processing liverpool
# 254 processing upernavik
# 255 processing sangueya
# palabuhanratu not found
# 257 processing yanam
# 258 processing victor harbor
# 259 processing balkanabat
# 260 processing alice springs
# 261 processing mackay
# 262 processing moba
# 263 processing mahon
# 264 processing gwanda
# 265 processing gravdal
# 266 processing broome
# tumannyy not found
# 268 processing anadyr
# 269 processing bilma
# 270 processing ostrovnoy
# 271 processing adamovka
# 272 processing shu
# 273 processing la ronge
# 274 processing katsuura
# 275 processing tukrah
# 276 processing alenquer
# 277 processing nsanje
# 278 processing cherskiy
# 279 processing hlotse
# tabiauea not found
# 281 processing constantine
# 282 processing ardmore
# 283 processing jacksonville
# 284 processing teya
# 285 processing ponta pora
# 286 processing obo
# 287 processing tacna
# 288 processing nantucket
# 289 processing mao
# 290 processing siyabuswa
# vaitupu not found
# 292 processing kuching
# 293 processing ust-ishim
# 294 processing diamantino
# 295 processing butterworth
# 296 processing cururupu
# 297 processing kavieng
# 298 processing mandera
# 299 processing flinders
# 300 processing gaffney
# 301 processing clyde river
# 302 processing spornoye
# 303 processing nemuro
# 304 processing jodiya
# 305 processing torbay
# 306 processing ranao
# 307 processing senanga
# 308 processing akdepe
# 309 processing pochutla
# 310 processing tarata
# 311 processing harper
# tsihombe not found
# burica not found
# 314 processing batagay
# 315 processing salinopolis
# 316 processing touros
# 317 processing tomatlan
# 318 processing saldanha
# 319 processing coihaique
# 320 processing karratha
# 321 processing manokwari
# 322 processing paamiut
# 323 processing cabanas
# 324 processing saint andrews
# 325 processing porto torres
# 326 processing sorong
# 327 processing beringovskiy
# el faiyum not found
# 329 processing grootfontein
# 330 processing hasaki
# 331 processing shelburne
# 332 processing yambio
# illoqqortoormiut not found
# 334 processing jerome
# 335 processing narsaq
# 336 processing devils lake
# 337 processing thiruvananthapuram
# 338 processing novobirilyussy
# 339 processing loksa
# 340 processing olinda
# 341 processing valparaiso
# 342 processing novoagansk
# 343 processing ciudad bolivar
# 344 processing mount isa
# 345 processing pitimbu
# 346 processing kysyl-syr
# 347 processing tonj
# 348 processing murgab
# 349 processing dalvik
# 350 processing berlevag
# 351 processing bafoulabe
# 352 processing macapa
# 353 processing comodoro rivadavia
# 354 processing kasongo-lunda
# sorvag not found
# 356 processing aklavik
# 357 processing verkhnetulomskiy
# umm durman not found
# 359 processing upata
# 360 processing takapau
# 361 processing udachnyy
# 362 processing kaspiyskiy
# 363 processing kahului
# 364 processing khorixas
# paradwip not found
# 366 processing harer
# 367 processing greytown
# 368 processing adrar
# 369 processing vestmannaeyjar
# 370 processing trapani
# 371 processing shimoda
# 372 processing fiumicino
# cagayan de tawi-tawi not found
# 374 processing libertador general san martin
# teul not found
# 376 processing feijo
# 377 processing inirida
# 378 processing accrington
# 379 processing wadi musa
# artyk not found
# 381 processing glenluce
# 382 processing linxia
# 383 processing guaraniacu
# 384 processing senneterre
# 385 processing dom pedrito
# 386 processing vila
# 387 processing dunedin
# 388 processing aranos
# 389 processing college place
# 390 processing presidencia roque saenz pena
# 391 processing kyren
# 392 processing naze
# 393 processing puerto el triunfo
# 394 processing irbil
# 395 processing chenzhou
# 396 processing cayenne
# 397 processing ust-maya
# 398 processing sao jose da coroa grande
# 399 processing tynda
# 400 processing conceicao do araguaia
# 401 processing broken hill
# 402 processing elmira
# 403 processing yushan
# 404 processing mitsamiouli
# 405 processing moanda
# 406 processing martapura
# 407 processing coquimbo
# 408 processing lorengau
# 409 processing oistins
# 410 processing general roca
# mrirt not found
# 412 processing havelock
# 413 processing lakselv
# 414 processing rocha
# 415 processing chicama
# 416 processing kaseda
# 417 processing nanortalik
# kuche not found
# 419 processing morondava
# 420 processing buraydah
# 421 processing namatanai
# 422 processing severnyy
# 423 processing kiruna
# 424 processing fereydun kenar
# 425 processing moree
# 426 processing ancud
# 427 processing salekhard
# 428 processing okmulgee
# 429 processing amazar
# 430 processing linguere
# 431 processing kushiro
# bolshegrivskoye not found
# 433 processing bodden town
# 434 processing makakilo city
# 435 processing andenes
# 436 processing siddipet
# 437 processing elizabeth city
# 438 processing sabang
# fort saint john not found
# 440 processing haikou
# 441 processing labuan
# 442 processing requena
# 443 processing bowen
# 444 processing hun
# 445 processing arlit
# karauzyak not found
# 447 processing roblin
# 448 processing zmeinogorsk
# 449 processing moose factory
# 450 processing manaus
# 451 processing dezhou
# 452 processing usinsk
# 453 processing aizpute
# 454 processing taveta
# karaul not found
# 456 processing belmonte
# 457 processing iguape
# 458 processing horlivka
# 459 processing ipixuna
# 460 processing taoudenni
# 461 processing ponyri
# 462 processing flin flon
# 463 processing boa vista
# 464 processing mangochi
# 465 processing ndele
# 466 processing suoyarvi
# 467 processing portland
# 468 processing hope
# 469 processing pemangkat
# 470 processing farafangana
# 471 processing port-gentil
# 472 processing mareeba
# 473 processing nguruka
# 474 processing labuhan
# 475 processing kawalu
# 476 processing meulaboh
# 477 processing taiyuan
# attawapiskat not found
# tidore not found
# 480 processing adeje
# 481 processing eskil
# 482 processing turukhansk
# 483 processing agualote
# 484 processing pangody
# 485 processing tazmalt
# 486 processing santa cruz
# 487 processing havre-saint-pierre
# 488 processing ahuimanu
# 489 processing gumdag
# 490 processing blagoyevo
# 491 processing boralday
# 492 processing roebourne
# 493 processing joetsu
# 494 processing halifax
# 495 processing vorontsovka
# 496 processing kozhva
# 497 processing ugoofaaru
# 498 processing ha tinh
# 499 processing warrnambool
# 500 processing hong gai
# 501 processing dire
# maloshuyka not found
# 503 processing gelemso
# 504 processing bang saphan
# 505 processing sept-iles
# 506 processing kindu
# 507 processing mmabatho
# dubenskiy not found
# 509 processing plouzane
# 510 processing ponnani
# 511 processing jalu
# 512 processing gilbues
# 513 processing nanakuli
# 514 processing batagay-alyta
# 515 processing warri
# 516 processing rawson
# 517 processing bagdarin
# 518 processing bathsheba
# 519 processing lakeside
# 520 processing tyup
# 521 processing grindavik
# 522 processing denpasar
# 523 processing rodos
# 524 processing kaeo
# 525 processing noyabrsk
# 526 processing san-pedro
# 527 processing mkuranga
# 528 processing talnakh
# 529 processing najran
# 530 processing fuyu
# 531 processing sechura
# 532 processing del rio
# jinchengjiang not found
# 534 processing los andes
# 535 processing ayagoz
# 536 processing sharjah
# 537 processing smoky lake
# westpunt not found
# 539 processing charters towers
# 540 processing bud
# 541 processing buta
# 542 processing amapa
# 543 processing honiara
# 544 processing great yarmouth
# 545 processing deputatskiy
# 546 processing huambo
# 547 processing praia da vitoria
# 548 processing pedra azul
# 549 processing morehead
# 550 processing montrose
# 551 processing qasigiannguit
# louisbourg not found
# 553 processing sandnessjoen
# bengkalis not found
# 555 processing kinkala
# 556 processing along
# 557 processing borogontsy
# 558 processing san quintin
# 559 processing semnan
# 560 processing micheweni
# 561 processing iralaya
# 562 processing machilipatnam
# 563 processing ginir
# 564 processing los llanos de aridane
# 565 processing juazeiro
# 566 processing manzanillo
# 567 processing miraflores
# 568 processing leon valley
# 569 processing watertown
# 570 processing poli
# 571 processing koutsouras
# 572 processing severo-kurilsk
# 573 processing geraldton
# 574 processing baykit
# 575 processing christchurch
# 576 processing nhulunbuy
# 577 processing wagar
# 578 processing road town
# 579 processing nuevo progreso
# 580 processing biak
# 581 processing dwarka
# 582 processing dembi dolo
# haibowan not found
# 584 processing lagos
# 585 processing cascais
# mullaitivu not found
# 587 processing buin
# 588 processing henties bay
# 589 processing lysychovo
# 590 processing husavik
# 591 processing neuquen
# 592 processing sundargarh
# 593 processing poum
# 594 processing yantai
# 595 processing harrismith
# 596 processing port keats
# 597 processing zhurivka
# 598 processing asau
# 599 processing palafrugell
# 600 processing koslan
# 601 processing mamallapuram

# %%
print(city_weather)
# Out:
# {'City': ['Ambilobe', 'Thompson', 'Busselton', 'Souillac', 'Hualmay', 'Kruisfontein', 'Hithadhoo', 'Hay River', 'Ushuaia', 'Tolbazy', 'Mataura', 'Port Hardy', 'Punta Arenas', 'Bluff', 'Berezovyy', 'Villa Carlos Paz', 'Te Anau', 'Castro', 'Port Alfred', 'Longyearbyen', 'Kaitangata', 'Ribeira Grande', 'Bongandanga', 'Hong Kong', 'Pevek', 'Havøysund', 'Forsytheganj', 'North Platte', 'Hofn', 'Rikitea', 'Isangel', 'Saint-Philippe', 'Puerto Ayora', 'Sørland', 'San Cristobal', 'Nikolskoye', 'Atuona', 'Vanavara', 'Saskylakh', 'Lagoa', 'Lander', 'Yulin', 'Ponta do Sol', 'Butaritari', 'Stepnyak', 'São João da Barra', 'Hobart', 'Iqaluit', 'Hermanus', 'Oussouye', 'Qaanaaq', 'Mount Vernon', 'Lebu', 'Provideniya', 'Palmer', 'Hamilton', 'Jiazi', 'Ust-Kuyga', 'Thurles', 'Yumen', 'Hiroshima', 'Pisco', 'Mtwara', 'Chapais', 'New Norfolk', 'Marabu', 'East London', 'Hilo', 'Avarua', 'Luanda', 'Leh', 'Kapaa', 'Yellowknife', 'Saint-Augustin', 'Kavaratti', 'Santa Isabel Rio Negro', 'Amqui', 'Dingle', 'Port Elizabeth', 'Peniche', 'Ţahţā', 'Hailar', 'Saint George', 'Gondanglegi', 'Meadow Lake', 'Tortoman', 'Samarai', 'Fortuna', 'Sobolevo', 'Albany', 'Ambovombe', 'Amga', 'Avera', 'Cape Town', 'Mahébourg', 'Griffith', 'Morón', 'Safford', 'Vao', 'Jamestown', 'Leningradskiy', 'Arraial do Cabo', 'Tasiilaq', 'Mandapam', 'Barrow', 'Ishigaki', 'Pacific Grove', 'Huejuquilla el Alto', 'Ambanja', 'Khatanga', 'Den Helder', 'George Town', 'Faanui', 'Esperance', 'Aswān', 'Rio Grande', 'Matara', 'Guerrero Negro', 'Buala', 'San Patricio', 'Doaba', 'Bambous Virieux', 'Nome', 'Airai', 'Vardø', 'Cidreira', 'Sinnamary', 'Tiksi', 'Constitución', 'Mar del Plata', 'Tuatapere', 'Padang', 'Safaga', 'Nabire', 'Guangzhou', 'Salalah', 'Codrington', 'Pasni', 'Camaquã', 'Wanning', 'Tura', 'Morristown', 'Vaini', 'Chokurdakh', 'Cairns', 'Bethel', 'Bitkine', 'Sawākin', 'Yenagoa', 'Siderno', 'Dikson', 'Marsá Maţrūḩ', 'Oga', 'Lanzhou', 'Cabo San Lucas', 'Lüderitz', 'Tuktoyaktuk', 'Arcata', 'Mchinji', 'São Filipe', 'Burnie', 'Mount Gambier', 'Ponta Delgada', 'Gräfenhainichen', 'Klaksvík', 'Esim', 'Sitka', 'Fuxin', 'Lompoc', 'Port Lincoln', 'Zyryanka', 'Puerto Maldonado', 'Olafsvik', 'Norman Wells', 'Emba', 'Abu Samrah', 'Othaya', 'Sagamu', 'College', 'Chany', 'Benguela', 'Sangar', 'Iberia', 'Kumul', 'Bengkulu', 'Mehamn', 'Karpathos', 'Carnarvon', 'Matale', 'Altay', 'Ilulissat', 'Huánuco', 'Nador', 'Brae', 'Ngunguru', 'Brigantine', 'Korla', 'Carballo', 'Oodweyne', 'San Ignacio', 'Zhigansk', 'Khor', 'Kars', 'Laas', 'Xining', 'Tara', 'Mitú', 'Manono', 'Joinville', 'Ussel', 'Acapulco de Juárez', 'Huarmey', 'Chui', 'Luena', 'Takoradze', 'Saint Paul Harbor', 'Alexandria', 'Gizo Government Station', 'Sola', 'Omboué', 'Sulangan', 'Bredasdorp', 'Zhangye', 'San Lorenzo', 'Pangnirtung', 'Saint-Joseph', 'Puerto Escondido', 'Opuwo', 'Lavrentiya', 'Port Augusta', 'Liverpool', 'Upernavik', 'Sanguéya', 'Yanam', 'Victor Harbor', 'Balkanabat', 'Alice Springs', 'Mackay', 'Moba', 'Mahon', 'Gwanda', 'Gravdal', 'Broome', 'Anadyr', 'Bilma', 'Ostrovnoy', 'Adamovka', 'Chu', 'La Ronge', 'Katsuura', 'Tūkrah', 'Alenquer', 'Nsanje', 'Cherskiy', 'Hlotse', 'Constantine', 'Ardmore', 'Jacksonville', 'Teya', 'Ponta Porã', 'Obo', 'Tacna', 'Nantucket', 'Mahon', 'Siyabuswa', 'Kuching', "Ust'-Ishim", 'Diamantino', 'Butterworth', 'Cururupu', 'Kavieng', 'Mandera', 'Flinders', 'Gaffney', 'Clyde River', 'Spornoye', 'Nemuro', 'Jodiya', 'Torbay', 'Ranao', 'Senanga', 'Akdepe', 'Pochutla', 'Tarata', 'Harper', 'Batagay', 'Salinópolis', 'Touros', 'Tomatlán', 'Saldanha', 'Coyhaique', 'Karratha', 'Manokwari', 'Paamiut', 'Cabañas', 'Saint Andrews', 'Porto Torres', 'Sorong', 'Beringovskiy', 'Grootfontein', 'Hasaki', 'Shelburne', 'Yambio', 'Jerome', 'Narsaq', 'Devils Lake', 'Trivandrum', 'Novobirilyussy', 'Loksa', 'Olinda', 'Valparaíso', 'Novoagansk', 'Ciudad Bolivar', 'Mount Isa', 'Pitimbu', 'Kysyl-Syr', 'Tonj', 'Murgab', 'Dalvik', 'Berlevåg', 'Bafoulabé', 'Macapá', 'Comodoro Rivadavia', 'Kasongo-Lunda', 'Aklavik', 'Verkhnetulomskiy', 'Up ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Display the DataFrame
# * Export the city data into a .csv. Open it up in excel or another program to make sure it looks as expected

# %%
weather_df = pd.DataFrame.from_dict(city_weather)
weather_df
# Out:
#               City  Cloudiness Country        Date  Humidity      Lat  \
# 0         Ambilobe         100      MG  1634782477        86 -13.2000
# 1         Thompson         100      CA  1634735579        76  55.7435
# 2        Busselton          93      AU  1634765418        64 -33.6500
# 3         Souillac           5      MU  1634780073        83 -20.5167
# 4          Hualmay          85      PE  1634726596        85 -11.0964
# ..             ...         ...     ...         ...       ...      ...
# 544       Zhurivka         100      UA  1634790304        64  50.5028
# 545           Asău           6      RO  1634791192        72  46.4333
# 546    Palafrugell          35      ES  1634796390        65  41.9174
# 547         Koslan         100      RU  1634788189        74  63.4564
# 548  Mahabalipuram          55      IN  1634776201        76  12.6264
#
#           Lng  Max Temp  Wind Speed
# 0     49.0500     68.20        2.84
# 1    -97.8558     30.04        5.39
# 2    115.3333     59.09       15.97
# 3     57.5167     71.37        7.63
# 4    -77.6139     63.75       10.80
# ..        ...       ...         ...
# 544   31.7849     48.18       15.86
# 545   26.4000     43.72        7.61
# 546    3.1631     68.56       10.31
# 547   48.8989     28.76       10.18
# 548   80.1722     80.65        4.29
#
# [549 rows x 9 columns]

# %%
weather_df.count()
# Out:
# City          549
# Cloudiness    549
# Country       549
# Date          549
# Humidity      549
# Lat           549
# Lng           549
# Max Temp      549
# Wind Speed    549
# dtype: int64

# %%
weather_df.to_csv('weather.csv',index=False)

# %%
check_df= pd.read_csv('weather.csv')
check_df
# Out:
#               City  Cloudiness Country        Date  Humidity      Lat  \
# 0         Ambilobe         100      MG  1634782477        86 -13.2000
# 1         Thompson         100      CA  1634735579        76  55.7435
# 2        Busselton          93      AU  1634765418        64 -33.6500
# 3         Souillac           5      MU  1634780073        83 -20.5167
# 4          Hualmay          85      PE  1634726596        85 -11.0964
# ..             ...         ...     ...         ...       ...      ...
# 544       Zhurivka         100      UA  1634790304        64  50.5028
# 545           Asău           6      RO  1634791192        72  46.4333
# 546    Palafrugell          35      ES  1634796390        65  41.9174
# 547         Koslan         100      RU  1634788189        74  63.4564
# 548  Mahabalipuram          55      IN  1634776201        76  12.6264
#
#           Lng  Max Temp  Wind Speed
# 0     49.0500     68.20        2.84
# 1    -97.8558     30.04        5.39
# 2    115.3333     59.09       15.97
# 3     57.5167     71.37        7.63
# 4    -77.6139     63.75       10.80
# ..        ...       ...         ...
# 544   31.7849     48.18       15.86
# 545   26.4000     43.72        7.61
# 546    3.1631     68.56       10.31
# 547   48.8989     28.76       10.18
# 548   80.1722     80.65        4.29
#
# [549 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Use matplotlib
# * Save the plotted figures as .pngs and embed those pngs in your readme file.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig,ax = plt.subplots()
ax.scatter(weather_df["Lat"], weather_df["Max Temp"],color = "steelblue", edgecolor = "black")
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")
ax.set_title("City Latitude vs. Max Temperature (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig,ax = plt.subplots()
ax.scatter(weather_df["Lat"], weather_df["Humidity"],color = "steelblue", edgecolor = "black")
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity(%)")
ax.set_title("City Latitude vs. Humidity (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig,ax = plt.subplots()
ax.scatter(weather_df["Lat"], weather_df["Cloudiness"],color = "steelblue", edgecolor = "black")
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness (%)")
ax.set_title("City Latitude vs. Cloudiness (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig,ax = plt.subplots()
ax.scatter(weather_df["Lat"], weather_df["Wind Speed"],color = "steelblue", edgecolor = "black")
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (mph)")
ax.set_title("City Latitude vs. Wind Speed (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %% [markdown]
# ### Use the Seaborn library to re-create 2-4 of the above plots.
# * Use the same data just make a different plot.
# * Note the differences in amount of code required to generate a similar plot.

# %%
sns.scatterplot(x=weather_df["Lat"], y=weather_df["Max Temp"],color = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Max Temperature (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %%
sns.scatterplot(x=weather_df["Lat"], y=weather_df["Humidity"],color = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Humidity (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %%
sns.scatterplot(x=weather_df["Lat"], y=weather_df["Cloudiness"],color = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %%
sns.scatterplot(x=weather_df["Lat"], y=weather_df["Wind Speed"],color = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.grid(linestyle='-', linewidth=2, alpha=0.5)
plt.show()

# %% [markdown]
# ### As a Data-Scientist:
# In addition to generating data, munging data and plotting data you will also be responsible for *interpreting* data.
# * Provide a written description of three observable trends based on the data.

# %% [markdown]
# - The cities near the equator have the highest temperture while cities farthest from the equator have the lowest temperature. The temperature decreases depending on how much farther the cities are from the equator.
# - Most of cities wind speed are in the lower range such as 0-10 mph. Some of the cities as it gets closer to the north pole, the wind speed increases as well
# - Most of cities have high humidity level of 80 to 100%

# %% [markdown]
# ### OPTIONAL Homework Problem:
# * Use a **different** api endpoint such as `Hourly Forecast 4 days` to get data.
# * Other weather api endpoints are documented [here](https://openweathermap.org/api).
# * You will have to change the URL parameters to get the data you want.
# * Get the data into a data structure of your choice. (Pandas, dicts, lists etc...)
# * Use the plotting library of your choice to make 1-4 plots of your choice.
