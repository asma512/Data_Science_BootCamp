# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1.	What scale of measurement applies to timeseries data? Is timeseries data continuous or discrete? Why?

# %% [markdown]
# - Timeseries data is measured on regularly spaced interval of time.
# - Timeseries data can be both contious and discrete
# - A time series is continuous when observations are made continuously through time
# - A time series is discrete when observations are taken only at specific times, usually equally spaced, even the
#   measured variable is a continuous variable.

# %% [markdown]
# ### 2.	What does ARIMA stand for? Break down and explain each piece in the name.

# %% [markdown]
# ARIMA stands for AutoRegressive Integrated Moving Average.
# - AR (Autoregression): A model that uses the dependent relationship between an observation and some number of lagged observations
# - I (Integrated): A model that uses the differencing of raw observations (e.g. subtracting an observation from the previous time step). Differencing in statistics is a transformation applied to time-series data in order to make it stationary. It eliminates trend and seasonality and stabilizing the mean of the time series.
# - MA (Moving Average): A model that uses the dependency between an observation and a residual error from a moving average model applied to lagged observations

# %% [markdown]
# ### 3.	Using the data in the temperatures/ folder. Write a function that efficiently converts every column to a different temperature scale: one that is more common than Kelvin.

# %%
#parse datetime & set index to datetime
df=pd.read_csv('temperatures/temperature.csv',parse_dates=['datetime'],index_col=['datetime'])
df.head(2)
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2012-10-01 12:00:00        NaN       NaN            NaN      NaN          NaN
# 2012-10-01 13:00:00     284.63    282.08         289.48    281.8       291.87
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2012-10-01 12:00:00        NaN        NaN      NaN          NaN     NaN  ...
# 2012-10-01 13:00:00     291.53     293.41    296.6       285.12  284.61  ...
#
#                      Philadelphia  New York  Montreal  Boston  Beersheba  \
# datetime
# 2012-10-01 12:00:00           NaN       NaN       NaN     NaN        NaN
# 2012-10-01 13:00:00        285.63    288.22    285.83  287.17     307.59
#
#                      Tel Aviv District   Eilat  Haifa  Nahariyya  Jerusalem
# datetime
# 2012-10-01 12:00:00                NaN  309.10    NaN        NaN        NaN
# 2012-10-01 13:00:00             305.47  310.58  304.4      304.4      303.5
#
# [2 rows x 36 columns]

# %%
#lambda function
celsius_df=df.apply(lambda x: x - 273.15)
celsius_df.head(3)
# Out:
#                      Vancouver  Portland  San Francisco   Seattle  \
# datetime
# 2012-10-01 12:00:00        NaN       NaN            NaN       NaN
# 2012-10-01 13:00:00  11.480000  8.930000      16.330000  8.650000
# 2012-10-01 14:00:00  11.479041  8.933252      16.324993  8.647217
#
#                      Los Angeles  San Diego  Las Vegas    Phoenix  \
# datetime
# 2012-10-01 12:00:00          NaN        NaN        NaN        NaN
# 2012-10-01 13:00:00    18.720000  18.380000  20.260000  23.450000
# 2012-10-01 14:00:00    18.718186  18.383501  20.253141  23.458508
#
#                      Albuquerque     Denver  ...  Philadelphia   New York  \
# datetime                                     ...
# 2012-10-01 12:00:00          NaN        NaN  ...           NaN        NaN
# 2012-10-01 13:00:00    11.970000  11.460000  ...     12.480000  15.070000
# 2012-10-01 14:00:00    12.004558  11.457306  ...     12.513208  15.097676
#
#                      Montreal     Boston  Beersheba  Tel Aviv District  \
# datetime
# 2012-10-01 12:00:00       NaN        NaN        NaN                NaN
# 2012-10-01 13:00:00  12.68000  14.020000      34.44              32.32
# 2012-10-01 14:00:00  12.68465  14.036092      34.44              31.16
#
#                          Eilat  Haifa  Nahariyya  Jerusalem
# datetime
# 2012-10-01 12:00:00  35.950000    NaN        NaN        NaN
# 2012-10-01 13:00:00  37.430000  31.25      31.25      30.35
# 2012-10-01 14:00:00  37.345769  31.25      31.25      30.35
#
# [3 rows x 36 columns]

# %% [markdown]
# ### 4.	Write a function that efficiently fills in missing values in every column, excluding trailing NANs. That is: if there's temperature data on either side of a timestamp, it should interpolate through it. But if data stopped being collected, your function should leave nans at the end.

# %%
def fill_nans(celsius_df):
    return celsius_df.interpolate(axis=0, method='linear', limit_area='inside') 

celsius_df = fill_nans(celsius_df)
celsius_df.tail(5)
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2017-11-29 20:00:00        NaN      8.85            NaN     7.67        20.40
# 2017-11-29 21:00:00        NaN      9.74            NaN     8.50        22.53
# 2017-11-29 22:00:00        NaN     10.24            NaN     9.60        22.81
# 2017-11-29 23:00:00        NaN      9.87            NaN     9.81        22.50
# 2017-11-30 00:00:00        NaN      9.13            NaN     9.89        21.78
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2017-11-29 20:00:00      19.00      16.39    21.56        12.57   16.41  ...
# 2017-11-29 21:00:00      19.59      17.46    22.44        13.30   17.55  ...
# 2017-11-29 22:00:00      19.43      18.19    23.10        13.29   16.56  ...
# 2017-11-29 23:00:00      19.46      19.00    24.00        12.99   16.02  ...
# 2017-11-30 00:00:00      18.25      18.49    24.00        11.55   12.03  ...
#
#                      Philadelphia  New York  Montreal  Boston  Beersheba  \
# datetime
# 2017-11-29 20:00:00         17.09       NaN      1.98   14.93        NaN
# 2017-11-29 21:00:00         16.09       NaN      0.98   12.87        NaN
# 2017-11-29 22:00:00         13.63       NaN      0.33   10.79        NaN
# 2017-11-29 23:00:00         11.42       NaN     -0.67    9.02        NaN
# 2017-11-30 00:00:00         10.27       NaN     -1.35    7.50        NaN
#
#                      Tel Aviv District  Eilat  Haifa  Nahariyya  Jerusalem
# datetime
# 2017-11-29 20:00:00                NaN    NaN    NaN        NaN        NaN
# 2017-11-29 21:00:00                NaN    NaN    NaN        NaN        NaN
# 2017-11-29 22:00:00                NaN    NaN    NaN        NaN        NaN
# 2017-11-29 23:00:00                NaN    NaN    NaN        NaN        NaN
# 2017-11-30 00:00:00                NaN    NaN    NaN        NaN        NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 5.	Find all cities A and B where city A is warmer than city B in the summer, but also colder than city B in the winter, on average.

# %%
# March to August - Summer
# September to Feb - Winter
#applies in order
conditions = [
    (celsius_df.index.month>=9),
    (celsius_df.index.month<=2),
    (celsius_df.index.month>2),
    (celsius_df.index.month<9),
]
values = ['winter', 'winter', 'summer', 'summer']
celsius_df['season'] = np.select(conditions, values)

# %%
#check if the conditions applied in order
celsius_df["season"].sample(10)
# Out:
# datetime
# 2016-06-27 04:00:00    summer
# 2017-07-09 18:00:00    summer
# 2014-05-15 09:00:00    summer
# 2017-08-09 21:00:00    summer
# 2015-08-30 04:00:00    summer
# 2016-05-31 16:00:00    summer
# 2017-11-27 00:00:00    winter
# 2015-12-05 03:00:00    winter
# 2015-03-14 01:00:00    summer
# 2014-06-10 19:00:00    summer
# Name: season, dtype: object

# %%
season_grp_avg = celsius_df.groupby('season').mean()
season_grp_avg
# Out:
#         Vancouver   Portland  San Francisco    Seattle  Los Angeles  \
# season
# summer  14.128676  15.388533      16.609003  14.441651    19.539008
# winter   7.341951   8.464415      13.424129   8.228979    15.939411
#
#         San Diego  Las Vegas    Phoenix  Albuquerque     Denver  ...  \
# season                                                           ...
# summer  18.519890  25.249739  27.403236    17.654461  14.531462  ...
# winter  15.678759  13.581605  17.520636     7.525674   5.075537  ...
#
#         Philadelphia   New York   Montreal     Boston  Beersheba  \
# season
# summer     17.013093  16.751792  12.675939  14.711171  21.320387
# winter      7.659853   7.809360   1.967683   6.739667  15.462265
#
#         Tel Aviv District      Eilat      Haifa  Nahariyya  Jerusalem
# season
# summer          23.633938  27.008922  24.048914  22.785912  22.759145
# winter          19.121127  19.734876  20.208544  19.126797  17.345889
#
# [2 rows x 36 columns]

# %%
cities = {"A":[],"B":[]}

for i in range(len(season_grp_avg.columns)):
    for j in range(i+1,len(season_grp_avg.columns)): 
        if season_grp_avg.iloc[0,i]>season_grp_avg.iloc[0,j] and season_grp_avg.iloc[1,i]<season_grp_avg.iloc[1,j]:
            cities["A"].append(season_grp_avg.columns[i])
            cities["B"].append(season_grp_avg.columns[j])
            
combined=pd.DataFrame(cities)
combined
# Out:
#                     A                  B
# 0           Las Vegas        San Antonio
# 1           Las Vegas             Dallas
# 2           Las Vegas            Houston
# 3           Las Vegas       Jacksonville
# 4           Las Vegas          Beersheba
# 5           Las Vegas  Tel Aviv District
# 6           Las Vegas              Haifa
# 7           Las Vegas          Nahariyya
# 8           Las Vegas          Jerusalem
# 9             Phoenix            Houston
# 10            Phoenix       Jacksonville
# 11            Phoenix              Miami
# 12            Phoenix  Tel Aviv District
# 13            Phoenix              Eilat
# 14            Phoenix              Haifa
# 15            Phoenix          Nahariyya
# 16        Albuquerque       Philadelphia
# 17        Albuquerque           New York
# 18        San Antonio       Jacksonville
# 19        San Antonio  Tel Aviv District
# 20        San Antonio              Haifa
# 21        San Antonio          Nahariyya
# 22        San Antonio          Jerusalem
# 23             Dallas          Beersheba
# 24             Dallas  Tel Aviv District
# 25             Dallas          Nahariyya
# 26             Dallas          Jerusalem
# 27            Houston       Jacksonville
# 28            Houston  Tel Aviv District
# 29            Houston              Haifa
# 30            Houston          Nahariyya
# 31        Minneapolis            Toronto
# 32        Minneapolis           Montreal
# 33            Chicago             Boston
# 34       Indianapolis       Philadelphia
# 35       Indianapolis           New York
# 36       Indianapolis             Boston
# 37            Detroit             Boston
# 38       Jacksonville  Tel Aviv District
# 39       Jacksonville          Nahariyya
# 40         Pittsburgh             Boston
# 41       Philadelphia           New York
# 42  Tel Aviv District          Nahariyya
# 43              Eilat              Haifa

# %% [markdown]
# ### 6.	For two of the cities you found in question 5 (there are many possible answers), clean up the data via rolling averages and plot a clear visual. Explain how rolling average differs from moving average (MA) model.

# %%
two_cities = celsius_df.loc[:,['Detroit','Boston']]
two_cities.tail(2)
# Out:
#                      Detroit  Boston
# datetime
# 2017-11-29 23:00:00     4.91    9.02
# 2017-11-30 00:00:00     3.44    7.50

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,2, sharey=True,figsize=(20,5))

ax[0].plot(two_cities.index, two_cities["Boston"].rolling('30D').mean())
ax[1].plot(two_cities.index, two_cities["Detroit"].rolling('30D').mean())
ax[0].set_xlabel('Time')
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Temperature')
ax[0].set_title('Boston-30 Day rolling Avg')
ax[1].set_title('Detroit-30 Day rolling Avg')
plt.show()

# %% [markdown]
# A rolling average continuously updates the average of a data set to include all the data in the set until that point.
# A moving average calculates the average of a data set for a specified period

# %% [markdown]
# ### 7.	Perform SARIMA on five cities, iterating through the cities programmatically. Explain your results.
# a.	Graph the predicted values 30 days out.

# %%
five_cities = celsius_df.loc[:,['New York','Boston','Detroit','Philadelphia','Las Vegas']]
five_cities = five_cities.resample('D').mean().dropna()
five_cities.isna().sum()
# Out:
# New York        0
# Boston          0
# Detroit         0
# Philadelphia    0
# Las Vegas       0
# dtype: int64

# %% [markdown]
# for i in cities_pct:
#         plot_acf(cities_pct[[i]], lags = 30,missing="drop",title="ACF-"+i)
#         plot_pacf(cities_pct[[i]], zero = False, lags = 30,title="PACF-"+i)

# %%
resDiff = sm.tsa.arma_order_select_ic(five_cities.Boston, ic='bic')
print('ARMA(p,q) =',resDiff['bic_min_order'])
# Out:
# ARMA(p,q) = (2, 2)

# %%
summary=[]

# %%
for i in five_cities:
    model = SARIMAX(five_cities[i], order=(2,1,2), seasonal_order=(2,1,2,12))
    res = model.fit()
    #forecasting for next 30 days
    forecast_df=pd.DataFrame(res.forecast(steps=30))
    summary.append(res.summary())
    forecast_df.plot()
    plt.title("Forecasting for 30 days out for "+i)
    plt.xlabel('Year')
    plt.ylabel('Temperature in Celcius')

# %% [markdown]
# - The temperature is seen decreasing overall towards the end of the month.
# - The temperature is seen slowly increasing in New York and Boston
# - Philadelphia and Las Vegas has the most variability in the temperature.
# - The temperature in Detroit seem to increasing but it is the coldest city out of all the chosen.

# %%
for i in summary:
    print(i)
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                           New York   No. Observations:                 1854
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood               -4631.993
# Date:                            Thu, 09 Dec 2021   AIC                           9281.987
# Time:                                    17:26:21   BIC                           9331.649
# Sample:                                10-01-2012   HQIC                          9300.298
#                                      - 10-28-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3144      0.066      4.743      0.000       0.184       0.444
# ar.L2          0.0349      0.055      0.636      0.525      -0.073       0.143
# ma.L1         -0.3802      0.063     -6.067      0.000      -0.503      -0.257
# ma.L2         -0.4108      0.059     -6.944      0.000      -0.527      -0.295
# ar.S.L12      -0.7692      0.282     -2.730      0.006      -1.322      -0.217
# ar.S.L24      -0.0508      0.022     -2.307      0.021      -0.094      -0.008
# ma.S.L12      -0.2539      0.282     -0.901      0.368      -0.806       0.299
# ma.S.L24      -0.7282      0.279     -2.607      0.009      -1.276      -0.181
# sigma2         8.7396      0.241     36.266      0.000       8.267       9.212
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               108.52
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.88   Skew:                            -0.06
# Prob(H) (two-sided):                  0.13   Kurtosis:                         4.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                             Boston   No. Observations:                 1854
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood               -4709.527
# Date:                            Thu, 09 Dec 2021   AIC                           9437.053
# Time:                                    17:26:54   BIC                           9486.716
# Sample:                                10-01-2012   HQIC                          9455.365
#                                      - 10-28-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3389      0.074      4.571      0.000       0.194       0.484
# ar.L2         -0.0150      0.058     -0.258      0.796      -0.129       0.099
# ma.L1         -0.4615      0.070     -6.564      0.000      -0.599      -0.324
# ma.L2         -0.3409      0.066     -5.138      0.000      -0.471      -0.211
# ar.S.L12      -0.8550      2.219     -0.385      0.700      -5.203       3.493
# ar.S.L24      -0.0404      0.096     -0.419      0.675      -0.229       0.149
# ma.S.L12      -0.1781      2.218     -0.080      0.936      -4.526       4.169
# ma.S.L24      -0.7964      2.187     -0.364      0.716      -5.082       3.490
# sigma2         9.5257      0.261     36.464      0.000       9.014      10.038
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                80.52
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.87   Skew:                            -0.03
# Prob(H) (two-sided):                  0.08   Kurtosis:                         4.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                            Detroit   No. Observations:                 1854
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood               -4787.688
# Date:                            Thu, 09 Dec 2021   AIC                           9593.376
# Time:                                    17:27:11   BIC                           9643.039
# Sample:                                10-01-2012   HQIC                          9611.688
#                                      - 10-28-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5263      0.076      6.881      0.000       0.376       0.676
# ar.L2         -0.0940      0.062     -1.510      0.131      -0.216       0.028
# ma.L1         -0.5965      0.074     -8.094      0.000      -0.741      -0.452
# ma.L2         -0.2165      0.070     -3.097      0.002      -0.354      -0.080
# ar.S.L12      -0.8007      0.502     -1.596      0.110      -1.784       0.183
# ar.S.L24      -0.0308      0.023     -1.343      0.179      -0.076       0.014
# ma.S.L12      -0.2205      0.506     -0.436      0.663      -1.212       0.770
# ma.S.L24      -0.7745      0.505     -1.533      0.125      -1.765       0.216
# sigma2        10.3006      0.408     25.243      0.000       9.501      11.100
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               194.45
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.71   Skew:                            -0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Philadelphia   No. Observations:                 1854
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood               -4760.634
# Date:                            Thu, 09 Dec 2021   AIC                           9539.268
# Time:                                    17:27:27   BIC                           9588.930
# Sample:                                10-01-2012   HQIC                          9557.579
#                                      - 10-28-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3729      0.066      5.662      0.000       0.244       0.502
# ar.L2         -0.0155      0.054     -0.285      0.776      -0.122       0.091
# ma.L1         -0.4417      0.063     -6.990      0.000      -0.566      -0.318
# ma.L2         -0.3690      0.060     -6.118      0.000      -0.487      -0.251
# ar.S.L12      -0.7532      0.327     -2.305      0.021      -1.394      -0.113
# ar.S.L24      -0.0227      0.024     -0.944      0.345      -0.070       0.024
# ma.S.L12      -0.2485      0.380     -0.653      0.514      -0.994       0.497
# ma.S.L24      -0.7506      0.352     -2.131      0.033      -1.441      -0.060
# sigma2         9.9823      1.853      5.388      0.000       6.351      13.613
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               157.15
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.94   Skew:                             0.04
# Prob(H) (two-sided):                  0.41   Kurtosis:                         4.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          Las Vegas   No. Observations:                 1854
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood               -4148.259
# Date:                            Thu, 09 Dec 2021   AIC                           8314.517
# Time:                                    17:27:37   BIC                           8364.180
# Sample:                                10-01-2012   HQIC                          8332.829
#                                      - 10-28-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6917      0.102      6.806      0.000       0.493       0.891
# ar.L2         -0.1271      0.087     -1.456      0.145      -0.298       0.044
# ma.L1         -0.6818      0.101     -6.752      0.000      -0.880      -0.484
# ma.L2         -0.1251      0.096     -1.302      0.193      -0.314       0.063
# ar.S.L12      -0.8980      0.527     -1.705      0.088      -1.930       0.134
# ar.S.L24       0.0074      0.028      0.264      0.792      -0.048       0.062
# ma.S.L12      -0.0878      0.527     -0.167      0.868      -1.121       0.945
# ma.S.L24      -0.9077      0.527     -1.723      0.085      -1.940       0.125
# sigma2         5.1438      0.247     20.862      0.000       4.661       5.627
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               181.45
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.18   Skew:                            -0.54
# Prob(H) (two-sided):                  0.04   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### 8.	Explain what you see when you perform results.summary() on the cities in question 7.

# %% [markdown]
# The p-value is less than 0.05 for ar.L1 for all the cities
# AIC & BIC are in the same range for all the cities

# %% [markdown]
# ### What do GARCH and ARCH Stand for? Break down and explain each piece in the names. Explain the difference between the two.

# %% [markdown]
# - ARCH and GARCH models have become important tools in the analysis of time series data, particularly in financial applications
#
# - An ARCH (autoregressive conditionally heteroscedastic) model is a model for the variance of a time series. ARCH models are used to describe a changing, possibly volatile variance
#
# - Generalized Autoregressive Conditional Heteroskedasticity, or GARCH, is an extension of the ARCH model that incorporates a moving average component together with the autoregressive component.

# %% [markdown]
# ![Screen%20Shot%202021-12-09%20at%206.04.50%20PM.png](attachment:Screen%20Shot%202021-12-09%20at%206.04.50%20PM.png)
