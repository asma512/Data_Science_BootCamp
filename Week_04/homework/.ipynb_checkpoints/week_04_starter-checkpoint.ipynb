# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
#
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
player_count = len(purchase_data["SN"].value_counts())
players = pd.DataFrame({"Total players": [player_count]})
players
# Out:
#    Total players
# 0            576

# %%
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_item = len(purchase_data["Item ID"].unique())

average_price = purchase_data["Price"].mean()

number_of_purchase = purchase_data["Purchase ID"].count()

total_revenue = purchase_data["Price"].sum()

purchasing_analysis_total = pd.DataFrame({"Number of Unique Items":[unique_item],
                                   "Average Price": average_price,
                                   "Number of Purchases": number_of_purchase,
                                   "Total Revenue": total_revenue})

format_mapping = {"Average Price": "${:,.2f}","Total Revenue": "${:,.2f}"}
purchasing_analysis_total.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_7cd07f40_339f_11ec_acd3_f018981507b9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7cd07f40_339f_11ec_acd3_f018981507b9level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7cd07f40_339f_11ec_acd3_f018981507b9row0_col0" class="data row0 col0" >183</td>
#                         <td id="T_7cd07f40_339f_11ec_acd3_f018981507b9row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_7cd07f40_339f_11ec_acd3_f018981507b9row0_col2" class="data row0 col2" >780</td>
# ...

# %%
# Out:
#    Number of Unique Items Average Price Number of Purchases Total Revenue
# 0                     183         $3.05                 780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender_group = purchase_data.groupby("Gender")

total_count_gender= gender_group["SN"].nunique()

percent_player = round((total_count_gender/player_count)*100,2)


gender_demo=pd.DataFrame({"Total Count":total_count_gender, "Pecentage of Players": percent_player})
gender_demo.index.name=None
gender_demo.sort_values(["Total Count"], ascending = False)
# Out:
#                        Total Count  Pecentage of Players
# Male                           484                 84.03
# Female                          81                 14.06
# Other / Non-Disclosed           11                  1.91

# %%
# Out:
#                        Total Count  Percentage of Players
# Male                           484                  84.03
# Female                          81                  14.06
# Other / Non-Disclosed           11                   1.91

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_count = gender_group["Purchase ID"].count()
average_purchase_price = gender_group["Price"].mean()
total_purchase_value = gender_group["Price"].sum()
avg_total_purchase_per_person = total_purchase_value/total_count_gender

gender_purchases=pd.DataFrame({"Purchase Count":purchase_count, 
                           "Average Purchase Price": average_purchase_price,
                          "Total Purchase Value": total_purchase_value,
                          "Avg total purchase per person":avg_total_purchase_per_person})

format_mapping = {"Average Purchase Price": "${:,.2f}","Total Purchase Value": "${:,.2f}",
                  "Avg total purchase per person":"${:,.2f}"}
gender_purchases.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_7fb56a2c_339f_11ec_acd3_f018981507b9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg total purchase per person</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7fb56a2c_339f_11ec_acd3_f018981507b9level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_7fb56a2c_339f_11ec_acd3_f018981507b9row0_col0" class="data row0 col0" >113</td>
#                         <td id="T_7fb56a2c_339f_11ec_acd3_f018981507b9row0_col1" class="data row0 col1" >$3.20</td>
#                         <td id="T_7fb56a2c_339f_11ec_acd3_f018981507b9row0_col2" class="data row0 col2" >$361.94</td>
# ...

# %%
# Out:
#                       Purchase Count Average Purchase Price  \
# Gender
# Female                           113                  $3.20
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
age_bins = [0, 9.99, 14.99, 19.99, 24.99, 29.99, 34.99, 39.99, 122]
age_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
purchase_data["Age Group"] = pd.cut(purchase_data["Age"],age_bins, labels=age_labels)


age_groups = purchase_data.groupby("Age Group")
total_count_age = age_groups["SN"].nunique()
percentage_of_players = round((total_count_age/player_count) *100,2)


age_demo= pd.DataFrame({"Total Count":total_count_age, "Percentage of Players":percentage_of_players})
age_demo.index.name=None
age_demo
# Out:
#        Total Count  Percentage of Players
# <10             17                   2.95
# 10-14           22                   3.82
# 15-19          107                  18.58
# 20-24          258                  44.79
# 25-29           77                  13.37
# 30-34           52                   9.03
# 35-39           31                   5.38
# 40+             12                   2.08

# %%
# Out:
#        Total Count  Percentage of Players
# <10             17                   2.95
# 10-14           22                   3.82
# 15-19          107                  18.58
# 20-24          258                  44.79
# 25-29           77                  13.37
# 30-34           52                   9.03
# 35-39           31                   5.38
# 40+             12                   2.08

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_count=age_groups["Purchase ID"].count()
average_purchase_price = age_groups["Price"].mean()
total_purchase_value = age_groups["Price"].sum()

avg_total_purchase_per_person = total_purchase_value/total_count_age

age_purchases =pd.DataFrame({"Purchase Count":purchase_count, 
                           "Average Purchase Price": average_purchase_price,
                          "Total Purchase Value": total_purchase_value,
                          "Avg total purchase per person":avg_total_purchase_per_person})

format_mapping = {"Average Purchase Price": "${:,.2f}","Total Purchase Value": "${:,.2f}",
                  "Avg total purchase per person":"${:,.2f}"}
age_purchases.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_836001e6_339f_11ec_acd3_f018981507b9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg total purchase per person</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_836001e6_339f_11ec_acd3_f018981507b9level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_836001e6_339f_11ec_acd3_f018981507b9row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_836001e6_339f_11ec_acd3_f018981507b9row0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_836001e6_339f_11ec_acd3_f018981507b9row0_col2" class="data row0 col2" >$77.13</td>
# ...

# %%
# Out:
#       Purchase Count Average Purchase Price Total Purchase Value  \
# 10-14             28                  $2.96               $82.78
# 15-19            136                  $3.04              $412.89
# 20-24            365                  $3.05            $1,114.06
# 25-29            101                  $2.90              $293.00
# 30-34             73                  $2.93              $214.00
# 35-39             41                  $3.60              $147.67
# 40+               13                  $2.94               $38.24
# <10               23                  $3.35               $77.13
#
#       Avg Total Purchase per Person
# 10-14                         $3.76
# 15-19                         $3.86
# 20-24                         $4.32
# 25-29                         $3.81
# 30-34                         $4.12
# 35-39                         $4.76
# 40+                           $3.19
# <10                           $4.54

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
spender_group= purchase_data.groupby("SN")

purchase_count = spender_group["Purchase ID"].count()

average_purchase_price = spender_group["Price"].mean()

total_purchase_value = spender_group["Price"].sum()

spenders = pd.DataFrame({'Purchase Count': purchase_count,
                             'Average Purchase Price': average_purchase_price,
                             'Total Purchase Value': total_purchase_value})

#spenders.sort_values('Total Purchase Value',ascending=False).head(5)

top_spenders=spenders.sort_values('Total Purchase Value',ascending=False).head(5)
format_mapping = {"Average Purchase Price": "${:,.2f}","Total Purchase Value": "${:,.2f}"}
top_spenders.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_855bb166_339f_11ec_acd3_f018981507b9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_855bb166_339f_11ec_acd3_f018981507b9level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_855bb166_339f_11ec_acd3_f018981507b9row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_855bb166_339f_11ec_acd3_f018981507b9row0_col1" class="data row0 col1" >$3.79</td>
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
items_group= purchase_data.groupby(["Item ID","Item Name"])

purchase_count =items_group["Purchase ID"].count()

average_purchase_price = items_group["Price"].mean()

total_purchase_value = items_group["Price"].sum()


popular_items = pd.DataFrame({'Purchase Count': purchase_count,
                             'Average Purchase Price': average_purchase_price,
                             'Total Purchase Value': total_purchase_value})

#popular_items.sort_values('Purchase Count',ascending=False).head(5)

top_items = popular_items.sort_values('Purchase Count',ascending=False).head(5)

format_mapping = {"Average Purchase Price": "${:,.2f}","Total Purchase Value": "${:,.2f}"}
top_items.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_871d1fc6_339f_11ec_acd3_f018981507b9" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_871d1fc6_339f_11ec_acd3_f018981507b9level0_row0" class="row_heading level0 row0" >178</th>
#                         <th id="T_871d1fc6_339f_11ec_acd3_f018981507b9level1_row0" class="row_heading level1 row0" >Oathbreaker, Last Hope of the Breaking Storm</th>
# ...

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 108     Extraction, Quickblade Of Trembling Hands                 9
# 82      Nirvana                                                   9
# 19      Pursuit, Cudgel of Necromancy                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
popular_items.sort_values('Total Purchase Value',ascending=False).head(5)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       Average Purchase Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                    4.23
# 82      Nirvana                                                         4.90
# 145     Fiery Glass Crusader                                            4.58
# 92      Final Critic                                                    4.88
# 103     Singed Scalpel                                                  4.35
#
# ...

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 92      Final Critic                                              8
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()
ax.bar(age_purchases.index, age_purchases["Average Purchase Price"]
           ,color = "blue")
ax.set_xlabel("Age Groups")
ax.set_ylabel("Avg Purchase Price")
ax.set_title("Purchasing Analysis by Age")
plt.show()

# %% [markdown]
# - The 35-39 age group has the highest average purchase price. The gaming industry should target this age group more.
# - The <10 age group has the second highest averahe purchase price. This is not surprising as young kids are more likely to buy optional items for their gaming experience.
# - The 25-29 age group has the lowest average purchase price. The game industry should not invest that much for this group.

# %% [markdown]
# ![Screen%20Shot%202021-10-22%20at%208.48.02%20PM.png](attachment:Screen%20Shot%202021-10-22%20at%208.48.02%20PM.png)
