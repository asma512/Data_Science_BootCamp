# %%
import pandas as pd

# %%
belize_listings_path = "belize_airbnb_listings.csv"
belize_df = pd.read_csv(belize_listings_path)
belize_df
# Out:
#             id                                               name    host_id  \
# 0        36666         Mo's Cozy Casa w/ veranda & access to dock     157752
# 1        36690  Mo's Cozy Cabana w/ comfy veranda & access to ...     157752
# 2       108932  Purple House eco solar  w/ ocean & wildlife views     563377
# 3       110483                            Michelo's fuchsia suite     567809
# 4       120115               Seaside Villas Second Floor Unit  #4     604999
# ...        ...                                                ...        ...
# 2791  48283996                                     Magical Island   17994012
# 2792  48287613   The Luxury Suite - Corozal, Bz- 3Bdr/2bthr CASA1  375769845
# 2793  48296096  Lagoon front apartment w/shared pool -  two mi...   76414486
# 2794  48296978                          Beachfront Poolside Condo   15308338
# 2795  48332221           Standard Room - San Ignacio Resort Hotel   60399527
#
# ...

# %%
belize_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
host_group=belize_df.groupby(["name"])

count = host_group['calculated_host_listings_count'].count()

price=host_group["price"].min()

df = pd.DataFrame({'Count': count,
                    'Price': price})
df.sample(50)
# Out:
#                                                     Count  Price
# name
# Peach House-(near airport,Wi-Fi, pool,tours,A.C.)       1     79
# Trellis House - Unit #4                                 1    131
# Villa Parrot Bed-& Breakfast in the jungle              1    163
# Wish You Were Here                                      1    302
# Parrot Nest Jungle Cabin (Gold Standard)                1    146
# NEW First Class Luxury Beachfront Vacation Villa!       1   1773
# Rachel's land Hotel Double Deluxe 406 Caye Caulker      1    140
# Revas Pearl - Two bedroom home                          1    232
# Sea View @DB Tower                                      1    131
# Secluded cabana property                                1    130
# Beautiful Condo with Ocean and Lagoon Views             1    252
# Oceanfront Suite Boutique Resort in Belize              1    258
# Casita Naranja - Beauty and the Beach                   1    332
# ...
