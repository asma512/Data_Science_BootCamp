# %%
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests

url = 'http://soundcloud.com/'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
executable_path = {'executable_path':ChromeDriverManager().install()}
browser = Browser('chrome',**executable_path,headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/asma/.wdm/drivers/chromedriver/mac64/98.0.4758.102/chromedriver] found in cache

# %%
browser.visit(url)
browser.links.find_by_partial_text('Explore').click()

# %%
soup = bs(browser.html,'html.parser')

categories = soup.find_all('div', class_='mixedSelectionModule')
print(categories)
# Out:
# [<div class="mixedSelectionModule"><div class="mixedSelectionModule__title">
# <h2 class="mixedSelectionModule__titleText" data-test-id="selection__title-text">Charts: Top 50</h2>
# <p class="mixedSelectionModule__description sc-type-small sc-text-body sc-type-light sc-text-secondary">The most played tracks on SoundCloud this week</p>
# </div>
# <div class="mixedSelectionGallery tileGallery m-fourPanels m-hasItemsForward m-transitionsEnabled"><div class="tileGallery__slider">
# <div class="tileGallery__sliderPeekContainer">
# <div class="tileGallery__sliderPanel">
# <div class="tileGallery__sliderPanelSlide" data-tile-index="0"><div class="systemPlaylistTile playableTile sc-mb-6x" data-actions="hover" data-playbutton="hover" data-test-id="system-playlist-tile"><div class="playableTile__artwork">
# <a class="playableTile__artworkLink" href="/discover/sets/charts-top:all-music:us">
# <div class="playableTile__image">
# ...

# %%
genres =[]
for category in categories:
    title = category.find('h2', class_='mixedSelectionModule__titleText').text
    if len(genres) == 5:
        break
    genres.append(title)

# %%
genres
# Out:
# ['Charts: Top 50', 'Charts: New & hot', 'Rap', 'New Music Now', 'Party Music']

# %% [markdown]
# I chose SoundCloud website for scrapping. I was intially attempting to scrape the top 50 songs. It was a in list format inside bunch of other div. I could not get a hold the right div and it was very unclear. I could not use find all method in some of the classes. Some class name had css attributes in them.
# Other members used xpath notation and regex (re.search) for the same page in the soundcloud website.
