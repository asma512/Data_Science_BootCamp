# %% [markdown]
# 1. Make sure you can get the API from class to work in Azure. Take a screenshot of it working and add the image to a jupyter notebook.

# %% [markdown]
# ![Screen%20Shot%202022-02-19%20at%201.14.44%20PM.png](attachment:Screen%20Shot%202022-02-19%20at%201.14.44%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202022-02-19%20at%201.16.14%20PM.png](attachment:Screen%20Shot%202022-02-19%20at%201.16.14%20PM.png)

# %% [markdown]
# 2. Loop through the API data in python using the /gdp/<"year> endpoint for your API. What does it look like? Is there a way to alter the html page to simplify what you see?

# %% [markdown]
# ![Screen%20Shot%202022-02-19%20at%201.21.35%20PM.png](attachment:Screen%20Shot%202022-02-19%20at%201.21.35%20PM.png)

# %% [markdown]
# It returns a list of dicitionaries. We can print by key and value line by line. We can use color and font changes within html.
